# %%
from models.quadnet import QuadCompNet
from models.cnet import SNet

arch = QuadCompNet

# %%
classes = range(10)

# %%
s_params = sum(p.numel() for p in SNet(len(classes)).parameters() if p.requires_grad)
quad_params = sum(p.numel() for p in QuadCompNet(len(classes)).parameters() if p.requires_grad)
print(f"SNet has {s_params} parameters")
print(f"QuadNet has {quad_params} parameters")
# Out:
# SNet has 77012 parameters
# QuadNet has 74764 parameters

# %%
import torch
import torchvision
import torch.nn as nn
import torchvision.transforms as transforms

import numpy as np

# %%
manualSeed = 999
torch.manual_seed(manualSeed)
torch.use_deterministic_algorithms(True)

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5,), (0.5,))])

batch_size = 1

classes = range(10)

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5,), (0.5,))])

batch_size = 1
n_train = 1000  # We will concentrate on the first 100 samples
n_valid = 4000

# Use pre-defined torchvision function to load MNIST train data
X_train = torchvision.datasets.MNIST(
    root="./data", train=True, download=True, transform=transform
)

# Filter out labels (originally 0-9), leaving only labels 0 and 1
idx = np.concatenate(
    [np.where(X_train.targets == c)[0][:n_train] for c in classes]
)
X_train.data = X_train.data[idx]
X_train.targets = X_train.targets[idx]



# Use pre-defined torchvision function to load MNIST train data
X_test = torchvision.datasets.MNIST(
    root="./data", train=True, download=True, transform=transform
)
idx = np.concatenate(
    [np.where(X_test.targets == c)[0][n_train:] for c in classes]
)
X_test.data = X_test.data[idx]
X_test.targets = X_test.targets[idx]



X_valid = torchvision.datasets.MNIST(
    root="./data", train=False, download=True, transform=transform
)
idx = np.concatenate(
    [np.where(X_valid.targets == c)[0][:n_valid] for c in classes]
)
X_valid.data = X_valid.data[idx]
X_valid.targets = X_valid.targets[idx]

# Define torch dataloader with filtered data
trainloader = torch.utils.data.DataLoader(X_train, batch_size=batch_size, shuffle=True)
validloader = torch.utils.data.DataLoader(X_valid, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(X_test, batch_size=batch_size, shuffle=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join(f'{labels[j]:5d}' for j in range(batch_size)))
# Out:
#     4

# %%
device = torch.device('cpu')

net = arch(len(classes)).to(device)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
def val_acc(net):
    correct, total = 0, 0
    for i, data in enumerate(validloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = torch.argmax(net(inputs), dim = 1)
        correct += torch.sum(outputs == labels).item()

        total += 1

    return correct / batch_size / total

# %%
best_acc, best_epoch, best_model = 0, -1, arch(num_classes=len(classes))
history = []

def train(model, lr=0.002, epochs=15, teacher=None, print_every=10, verbose=True):
    global best_acc, best_model, history
    best_epoch = -1

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    patience = 3
    for epoch in range(epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data

            # labels = torch.tensor([1. if labels.item() == x else 0. for x in classes]).view(1, -1)

            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)

            if teacher is None:
                loss = criterion(outputs, labels)
            else:
                with torch.no_grad():
                    teacher_preds = teacher(inputs).detach()
                    
                teaching_loss = criterion(outputs, teacher_preds)
                loss = criterion(outputs, labels) + teaching_loss
                    
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            
            
                
            # if i == batches: break
            if (i+1) % print_every == 0:
                if verbose:
                    print(f'[{epoch + 1}, {i+1}] loss: {running_loss / print_every:.3f}')
                    print(outputs[0], labels[0])
                # print(outputs[1], labels[1])
                with torch.no_grad():
                    acc = val_acc(model)
                
                if acc > best_acc:
                    best_acc = acc
                    best_epoch = epoch
                    best_model.load_state_dict(model.state_dict())

                history.append([running_loss / print_every, acc])
                running_loss = 0.0
                if verbose:
                    print(f"Validation Accuracy: {acc:.3f}")

                

                if acc == 1: break
        if acc == 1: break

        if best_acc > 0.6 and epoch > best_epoch + patience: break
                
            

        # print(f'{epoch + 1} loss: {running_loss / n_samples:.3f}')
        # print(outputs[0], labels[0])
        # # print(outputs[1], labels[1])
        # with torch.no_grad():
        #     acc = val_acc(model)
        # print("Validation Accuracy:", acc)
        
        # if acc > best_acc:
        #     best_acc = acc
        #     best_batch = i
        #     best_model.load_state_dict(model.state_dict())

        # if i > best_batch + batch_patience: break

        # history.append([running_loss / n_samples, acc])
        
        # running_loss = 0.0


    print('Finished Training')
    return best_model, history

# %%
best_model, history = train(net, lr=0.002, epochs=50)
# Out:
# [1, 10] loss: 2.384
# tensor([-0.3939,  0.1323,  0.1777,  0.4073, -0.5134,  0.1331,  0.4532, -0.3819,
#          0.1288, -0.1781], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.096
# [1, 20] loss: 2.372
# tensor([ 0.0889,  0.2100,  0.0740,  0.1723, -0.1486, -0.0673,  0.2675,  0.0226,
#          0.1588, -0.1438], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.096
# [1, 30] loss: 2.282
# tensor([ 0.1393,  0.2812,  0.0191,  0.1142, -0.0992, -0.0711,  0.1729,  0.0860,
#          0.1310, -0.1468], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 40] loss: 2.359
# tensor([ 0.0282,  0.3654, -0.0576,  0.1044, -0.1567,  0.0302,  0.0379,  0.0458,
#          0.0673, -0.1509], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.114
# [1, 50] loss: 2.339
# tensor([-0.0745,  0.4191, -0.1380,  0.1054, -0.2354,  0.1346, -0.0867, -0.0104,
#          0.0130, -0.1541], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 60] loss: 2.433
# tensor([ 0.0841,  0.2933, -0.0084,  0.1071, -0.1605, -0.0227,  0.1157,  0.0600,
#          0.1098, -0.1395], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 70] loss: 2.269
# tensor([ 0.1565,  0.2334,  0.0502,  0.1097, -0.1221, -0.0981,  0.2191,  0.0985,
#          0.1554, -0.1321], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.114
# [1, 80] loss: 2.328
# tensor([ 0.1552,  0.2244,  0.0594,  0.1106, -0.1216, -0.1017,  0.2365,  0.0975,
#          0.1556, -0.1298], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.096
# [1, 90] loss: 2.301
# tensor([ 0.1489,  0.2223,  0.0628,  0.1154, -0.1273, -0.0975,  0.2361,  0.0974,
#          0.1496, -0.1267], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 100] loss: 2.265
# tensor([ 0.1457,  0.2194,  0.0607,  0.1172, -0.1312, -0.0967,  0.2455,  0.0932,
#          0.1489, -0.1265], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 110] loss: 2.294
# tensor([ 0.1419,  0.2183,  0.0559,  0.1152, -0.1250, -0.0970,  0.2513,  0.0917,
#          0.1524, -0.1297], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.096
# [1, 120] loss: 2.238
# tensor([ 0.1497,  0.2210,  0.0537,  0.1136, -0.1207, -0.1006,  0.2529,  0.0860,
#          0.1522, -0.1326], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 130] loss: 2.332
# tensor([ 0.1523,  0.2252,  0.0493,  0.1146, -0.1227, -0.0996,  0.2552,  0.0829,
#          0.1511, -0.1346], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 140] loss: 2.290
# tensor([ 0.1529,  0.2260,  0.0470,  0.1200, -0.1189, -0.0934,  0.2529,  0.0777,
#          0.1474, -0.1389], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 150] loss: 2.357
# tensor([ 0.1526,  0.2215,  0.0462,  0.1317, -0.1167, -0.0895,  0.2476,  0.0704,
#          0.1505, -0.1442], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 160] loss: 2.315
# tensor([ 0.1539,  0.2186,  0.0508,  0.1345, -0.1155, -0.0796,  0.2409,  0.0631,
#          0.1495, -0.1499], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.096
# [1, 170] loss: 2.381
# tensor([ 0.1565,  0.2130,  0.0520,  0.1352, -0.1174, -0.0730,  0.2376,  0.0633,
#          0.1445, -0.1468], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 180] loss: 2.278
# tensor([ 0.1565,  0.2150,  0.0539,  0.1341, -0.1099, -0.0735,  0.2341,  0.0616,
#          0.1380, -0.1445], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.096
# [1, 190] loss: 2.265
# tensor([ 0.1608,  0.2148,  0.0562,  0.1305, -0.1099, -0.0734,  0.2377,  0.0640,
#          0.1315, -0.1474], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.096
# [1, 200] loss: 2.382
# tensor([ 0.1655,  0.2096,  0.0594,  0.1248, -0.1105, -0.0726,  0.2397,  0.0604,
#          0.1307, -0.1434], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.096
# [1, 210] loss: 2.305
# tensor([ 0.1633,  0.2084,  0.0620,  0.1183, -0.1021, -0.0757,  0.2406,  0.0572,
#          0.1278, -0.1364], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 220] loss: 2.365
# tensor([ 0.1576,  0.2105,  0.0658,  0.1152, -0.0974, -0.0803,  0.2437,  0.0557,
#          0.1219, -0.1304], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.096
# [1, 230] loss: 2.238
# tensor([ 0.1536,  0.2061,  0.0700,  0.1143, -0.0938, -0.0855,  0.2471,  0.0570,
#          0.1186, -0.1261], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.096
# [1, 240] loss: 2.338
# tensor([ 0.1489,  0.2030,  0.0841,  0.1119, -0.0957, -0.0897,  0.2539,  0.0531,
#          0.1135, -0.1263], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.096
# [1, 250] loss: 2.323
# tensor([ 0.1423,  0.2028,  0.0881,  0.1086, -0.0885, -0.0853,  0.2520,  0.0493,
#          0.1123, -0.1267], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 260] loss: 2.326
# tensor([ 0.1393,  0.2015,  0.0868,  0.1028, -0.0813, -0.0855,  0.2506,  0.0454,
#          0.1215, -0.1268], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 270] loss: 2.284
# tensor([ 0.1419,  0.1966,  0.0851,  0.0961, -0.0714, -0.0892,  0.2491,  0.0540,
#          0.1228, -0.1305], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 280] loss: 2.346
# tensor([ 0.1465,  0.1981,  0.0839,  0.0909, -0.0658, -0.0942,  0.2441,  0.0663,
#          0.1185, -0.1331], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.096
# [1, 290] loss: 2.244
# tensor([ 0.1481,  0.1959,  0.0860,  0.0933, -0.0626, -0.0965,  0.2393,  0.0750,
#          0.1122, -0.1355], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 300] loss: 2.367
# tensor([ 0.1475,  0.1922,  0.0846,  0.0937, -0.0601, -0.0951,  0.2430,  0.0734,
#          0.1116, -0.1368], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 310] loss: 2.312
# tensor([ 0.1478,  0.1857,  0.0850,  0.0957, -0.0539, -0.0943,  0.2396,  0.0764,
#          0.1113, -0.1397], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 320] loss: 2.371
# tensor([ 0.1488,  0.1782,  0.0858,  0.0962, -0.0494, -0.0909,  0.2337,  0.0828,
#          0.1091, -0.1414], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.096
# [1, 330] loss: 2.335
# tensor([ 0.1511,  0.1728,  0.0889,  0.0950, -0.0465, -0.0875,  0.2267,  0.0805,
#          0.1075, -0.1364], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 340] loss: 2.294
# tensor([ 0.1501,  0.1680,  0.0930,  0.0932, -0.0429, -0.0880,  0.2230,  0.0784,
#          0.1133, -0.1370], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 350] loss: 2.308
# tensor([ 0.1481,  0.1630,  0.0941,  0.0954, -0.0438, -0.0862,  0.2239,  0.0789,
#          0.1173, -0.1403], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.096
# [1, 360] loss: 2.247
# tensor([ 0.1479,  0.1596,  0.0909,  0.0957, -0.0477, -0.0853,  0.2272,  0.0784,
#          0.1206, -0.1367], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 370] loss: 2.296
# tensor([ 0.1524,  0.1632,  0.0857,  0.1004, -0.0506, -0.0871,  0.2258,  0.0750,
#          0.1237, -0.1373], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 380] loss: 2.254
# tensor([ 0.1561,  0.1627,  0.0803,  0.0984, -0.0533, -0.0877,  0.2288,  0.0730,
#          0.1288, -0.1361], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 390] loss: 2.293
# tensor([ 0.1530,  0.1621,  0.0834,  0.0931, -0.0499, -0.0911,  0.2367,  0.0677,
#          0.1314, -0.1373], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.096
# [1, 400] loss: 2.302
# tensor([ 0.1471,  0.1608,  0.0869,  0.0936, -0.0480, -0.0941,  0.2389,  0.0683,
#          0.1358, -0.1415], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 410] loss: 2.244
# tensor([ 0.1484,  0.1605,  0.0851,  0.0912, -0.0511, -0.0920,  0.2414,  0.0694,
#          0.1410, -0.1468], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.096
# [1, 420] loss: 2.301
# tensor([ 0.1491,  0.1582,  0.0900,  0.0864, -0.0495, -0.0951,  0.2447,  0.0665,
#          0.1427, -0.1478], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.096
# [1, 430] loss: 2.323
# tensor([ 0.1478,  0.1604,  0.0936,  0.0885, -0.0465, -0.1000,  0.2466,  0.0637,
#          0.1390, -0.1487], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.096
# [1, 440] loss: 2.272
# tensor([ 0.1439,  0.1619,  0.0984,  0.0846, -0.0480, -0.1056,  0.2450,  0.0692,
#          0.1369, -0.1420], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 450] loss: 2.385
# tensor([ 0.1377,  0.1620,  0.1049,  0.0786, -0.0456, -0.1057,  0.2420,  0.0709,
#          0.1387, -0.1401], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 460] loss: 2.258
# tensor([ 0.1368,  0.1595,  0.1088,  0.0718, -0.0480, -0.0972,  0.2409,  0.0694,
#          0.1394, -0.1385], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 470] loss: 2.309
# tensor([ 0.1346,  0.1620,  0.1089,  0.0692, -0.0508, -0.0981,  0.2426,  0.0772,
#          0.1367, -0.1397], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.096
# [1, 480] loss: 2.312
# tensor([ 0.1304,  0.1694,  0.1067,  0.0638, -0.0489, -0.1022,  0.2421,  0.0826,
#          0.1342, -0.1357], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 490] loss: 2.255
# tensor([ 0.1273,  0.1731,  0.1043,  0.0573, -0.0507, -0.1029,  0.2436,  0.0914,
#          0.1318, -0.1331], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 500] loss: 2.269
# tensor([ 0.1214,  0.1725,  0.1043,  0.0516, -0.0475, -0.1070,  0.2483,  0.1000,
#          0.1323, -0.1360], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 510] loss: 2.277
# tensor([ 0.1170,  0.1732,  0.1035,  0.0562, -0.0422, -0.1117,  0.2530,  0.0986,
#          0.1319, -0.1409], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 520] loss: 2.292
# tensor([ 0.1157,  0.1730,  0.1080,  0.0548, -0.0440, -0.1099,  0.2525,  0.0980,
#          0.1339, -0.1439], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.096
# [1, 530] loss: 2.344
# tensor([ 0.1121,  0.1724,  0.1096,  0.0616, -0.0461, -0.1105,  0.2535,  0.0933,
#          0.1330, -0.1412], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 540] loss: 2.314
# tensor([ 0.1123,  0.1738,  0.1066,  0.0614, -0.0419, -0.1113,  0.2539,  0.0884,
#          0.1313, -0.1363], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 550] loss: 2.322
# tensor([ 0.1113,  0.1755,  0.1098,  0.0586, -0.0389, -0.1066,  0.2492,  0.0895,
#          0.1273, -0.1375], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 560] loss: 2.275
# tensor([ 0.1100,  0.1756,  0.1097,  0.0557, -0.0412, -0.0978,  0.2492,  0.0891,
#          0.1291, -0.1417], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 570] loss: 2.282
# tensor([ 0.1143,  0.1717,  0.1055,  0.0526, -0.0451, -0.0957,  0.2485,  0.0953,
#          0.1343, -0.1436], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 580] loss: 2.342
# tensor([ 0.1193,  0.1717,  0.1034,  0.0491, -0.0436, -0.0938,  0.2490,  0.0961,
#          0.1330, -0.1468], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.096
# [1, 590] loss: 2.326
# tensor([ 0.1167,  0.1721,  0.0990,  0.0490, -0.0384, -0.0878,  0.2465,  0.0920,
#          0.1362, -0.1476], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.096
# [1, 600] loss: 2.306
# tensor([ 0.1110,  0.1690,  0.1003,  0.0480, -0.0303, -0.0858,  0.2497,  0.0860,
#          0.1361, -0.1478], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.096
# [1, 610] loss: 2.284
# tensor([ 0.1042,  0.1717,  0.1017,  0.0430, -0.0277, -0.0889,  0.2544,  0.0795,
#          0.1333, -0.1359], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 620] loss: 2.301
# tensor([ 0.1014,  0.1796,  0.0979,  0.0454, -0.0306, -0.0939,  0.2558,  0.0766,
#          0.1332, -0.1300], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.096
# [1, 630] loss: 2.409
# tensor([ 0.0959,  0.1788,  0.1001,  0.0470, -0.0354, -0.0859,  0.2515,  0.0740,
#          0.1369, -0.1272], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 640] loss: 2.287
# tensor([ 0.0963,  0.1737,  0.0989,  0.0474, -0.0410, -0.0703,  0.2452,  0.0749,
#          0.1378, -0.1267], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 650] loss: 2.299
# tensor([ 0.1014,  0.1706,  0.1007,  0.0522, -0.0437, -0.0681,  0.2422,  0.0751,
#          0.1352, -0.1290], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 660] loss: 2.337
# tensor([ 0.1046,  0.1673,  0.0996,  0.0521, -0.0461, -0.0599,  0.2404,  0.0761,
#          0.1328, -0.1303], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 670] loss: 2.286
# tensor([ 0.1023,  0.1639,  0.0966,  0.0530, -0.0452, -0.0591,  0.2388,  0.0866,
#          0.1343, -0.1346], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 680] loss: 2.292
# tensor([ 0.1001,  0.1617,  0.0951,  0.0576, -0.0426, -0.0627,  0.2337,  0.0941,
#          0.1385, -0.1392], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 690] loss: 2.300
# tensor([ 0.0945,  0.1652,  0.0947,  0.0563, -0.0362, -0.0650,  0.2271,  0.0960,
#          0.1439, -0.1407], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 700] loss: 2.295
# tensor([ 0.0959,  0.1618,  0.0949,  0.0553, -0.0343, -0.0680,  0.2282,  0.0953,
#          0.1484, -0.1420], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 710] loss: 2.273
# tensor([ 0.0957,  0.1558,  0.1055,  0.0510, -0.0376, -0.0685,  0.2290,  0.0991,
#          0.1484, -0.1446], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 720] loss: 2.298
# tensor([ 0.0926,  0.1543,  0.1150,  0.0449, -0.0399, -0.0644,  0.2280,  0.1004,
#          0.1481, -0.1468], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.096
# [1, 730] loss: 2.397
# tensor([ 0.0915,  0.1562,  0.1172,  0.0382, -0.0400, -0.0649,  0.2289,  0.0964,
#          0.1446, -0.1358], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.096
# [1, 740] loss: 2.305
# tensor([ 0.0923,  0.1554,  0.1176,  0.0313, -0.0306, -0.0658,  0.2292,  0.0906,
#          0.1395, -0.1273], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.096
# [1, 750] loss: 2.353
# tensor([ 0.0958,  0.1520,  0.1177,  0.0320, -0.0291, -0.0601,  0.2283,  0.0840,
#          0.1367, -0.1249], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 760] loss: 2.318
# tensor([ 0.1034,  0.1459,  0.1135,  0.0294, -0.0243, -0.0540,  0.2305,  0.0817,
#          0.1312, -0.1252], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.096
# [1, 770] loss: 2.345
# tensor([ 0.1137,  0.1403,  0.1077,  0.0270, -0.0159, -0.0424,  0.2284,  0.0764,
#          0.1246, -0.1284], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 780] loss: 2.264
# tensor([ 0.1158,  0.1485,  0.1059,  0.0233, -0.0114, -0.0389,  0.2259,  0.0736,
#          0.1178, -0.1294], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 790] loss: 2.279
# tensor([ 0.1155,  0.1610,  0.1047,  0.0175, -0.0097, -0.0363,  0.2277,  0.0691,
#          0.1107, -0.1302], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.096
# [1, 800] loss: 2.313
# tensor([ 0.1116,  0.1648,  0.1000,  0.0170, -0.0130, -0.0333,  0.2366,  0.0666,
#          0.1087, -0.1299], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.096
# [1, 810] loss: 2.302
# tensor([ 0.1132,  0.1614,  0.0941,  0.0177, -0.0174, -0.0275,  0.2378,  0.0663,
#          0.1112, -0.1274], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.096
# [1, 820] loss: 2.314
# tensor([ 0.1148,  0.1561,  0.0876,  0.0192, -0.0193, -0.0203,  0.2386,  0.0694,
#          0.1135, -0.1304], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 830] loss: 2.312
# tensor([ 0.1142,  0.1554,  0.0855,  0.0211, -0.0156, -0.0127,  0.2349,  0.0683,
#          0.1128, -0.1353], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 840] loss: 2.296
# tensor([ 0.1138,  0.1525,  0.0937,  0.0178, -0.0137, -0.0138,  0.2326,  0.0708,
#          0.1130, -0.1389], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.096
# [1, 850] loss: 2.318
# tensor([ 0.1118,  0.1467,  0.0967,  0.0280, -0.0170, -0.0181,  0.2332,  0.0724,
#          0.1122, -0.1376], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 860] loss: 2.332
# tensor([ 0.1090,  0.1399,  0.1003,  0.0299, -0.0221, -0.0183,  0.2344,  0.0768,
#          0.1074, -0.1287], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 870] loss: 2.376
# tensor([ 0.1053,  0.1340,  0.1002,  0.0298, -0.0255, -0.0112,  0.2345,  0.0788,
#          0.1011, -0.1185], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 880] loss: 2.298
# tensor([ 0.1020,  0.1334,  0.1006,  0.0262, -0.0286, -0.0079,  0.2319,  0.0824,
#          0.0943, -0.1059], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 890] loss: 2.297
# tensor([ 0.0998,  0.1342,  0.1096,  0.0204, -0.0292, -0.0106,  0.2281,  0.0838,
#          0.0953, -0.1038], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.096
# [1, 900] loss: 2.297
# tensor([ 0.1116,  0.1321,  0.1126,  0.0173, -0.0291, -0.0155,  0.2220,  0.0851,
#          0.0945, -0.1029], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 910] loss: 2.233
# tensor([ 0.1206,  0.1344,  0.1162,  0.0130, -0.0331, -0.0211,  0.2172,  0.0814,
#          0.1045, -0.1059], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 920] loss: 2.326
# tensor([ 0.1257,  0.1337,  0.1167,  0.0119, -0.0344, -0.0269,  0.2168,  0.0757,
#          0.1154, -0.1075], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 930] loss: 2.288
# tensor([ 0.1254,  0.1366,  0.1145,  0.0157, -0.0318, -0.0329,  0.2161,  0.0717,
#          0.1199, -0.1077], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 940] loss: 2.329
# tensor([ 0.1207,  0.1370,  0.1190,  0.0162, -0.0328, -0.0348,  0.2151,  0.0722,
#          0.1232, -0.1086], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 950] loss: 2.339
# tensor([ 0.1167,  0.1336,  0.1189,  0.0245, -0.0339, -0.0269,  0.2100,  0.0686,
#          0.1241, -0.1082], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.096
# [1, 960] loss: 2.315
# tensor([ 0.1166,  0.1330,  0.1187,  0.0303, -0.0339, -0.0262,  0.2060,  0.0673,
#          0.1224, -0.1062], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.096
# [1, 970] loss: 2.320
# tensor([ 0.1153,  0.1316,  0.1231,  0.0327, -0.0337, -0.0231,  0.2013,  0.0707,
#          0.1172, -0.1072], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 980] loss: 2.312
# tensor([ 0.1119,  0.1287,  0.1267,  0.0353, -0.0318, -0.0175,  0.1949,  0.0757,
#          0.1143, -0.1107], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 990] loss: 2.276
# tensor([ 0.1061,  0.1343,  0.1337,  0.0384, -0.0351, -0.0176,  0.1901,  0.0778,
#          0.1115, -0.1119], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.096
# [1, 1000] loss: 2.311
# tensor([ 0.1095,  0.1378,  0.1349,  0.0378, -0.0339, -0.0149,  0.1890,  0.0741,
#          0.1084, -0.1162], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.096
# [1, 1010] loss: 2.329
# tensor([ 0.1092,  0.1364,  0.1310,  0.0358, -0.0227, -0.0131,  0.1876,  0.0751,
#          0.1067, -0.1196], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.096
# [1, 1020] loss: 2.317
# tensor([ 0.1099,  0.1312,  0.1270,  0.0307, -0.0107, -0.0137,  0.1909,  0.0766,
#          0.1020, -0.1179], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.096
# [1, 1030] loss: 2.318
# tensor([ 0.1090,  0.1265,  0.1291,  0.0291, -0.0006, -0.0163,  0.1885,  0.0779,
#          0.0986, -0.1163], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 1040] loss: 2.329
# tensor([ 0.1041,  0.1227,  0.1311,  0.0329,  0.0063, -0.0199,  0.1828,  0.0815,
#          0.0989, -0.1152], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.096
# [1, 1050] loss: 2.326
# tensor([ 0.1005,  0.1166,  0.1334,  0.0347,  0.0099, -0.0133,  0.1803,  0.0795,
#          0.0970, -0.1138], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.096
# [1, 1060] loss: 2.288
# tensor([ 0.0963,  0.1111,  0.1353,  0.0429,  0.0078, -0.0083,  0.1777,  0.0762,
#          0.1021, -0.1169], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.096
# [1, 1070] loss: 2.329
# tensor([ 0.0934,  0.1076,  0.1403,  0.0429,  0.0066, -0.0033,  0.1733,  0.0773,
#          0.0996, -0.1141], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.096
# [1, 1080] loss: 2.303
# tensor([ 0.0936,  0.1098,  0.1430,  0.0466,  0.0061, -0.0027,  0.1700,  0.0753,
#          0.0972, -0.1155], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.096
# [1, 1090] loss: 2.303
# tensor([ 0.0932,  0.1068,  0.1446,  0.0471,  0.0107, -0.0027,  0.1671,  0.0740,
#          0.1011, -0.1191], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.096
# [1, 1100] loss: 2.253
# tensor([ 0.0907,  0.1038,  0.1520,  0.0446,  0.0125, -0.0039,  0.1673,  0.0722,
#          0.1029, -0.1203], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.096
# [1, 1110] loss: 2.294
# tensor([ 0.0917,  0.1011,  0.1654,  0.0421,  0.0092, -0.0041,  0.1634,  0.0704,
#          0.1036, -0.1227], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.103
# [1, 1120] loss: 2.333
# tensor([ 0.0931,  0.0987,  0.1721,  0.0398,  0.0040,  0.0023,  0.1573,  0.0704,
#          0.1028, -0.1213], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.103
# [1, 1130] loss: 2.324
# tensor([ 0.1005,  0.0938,  0.1719,  0.0418,  0.0016,  0.0128,  0.1504,  0.0701,
#          0.0989, -0.1234], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [1, 1140] loss: 2.266
# tensor([ 0.1040,  0.0979,  0.1751,  0.0414, -0.0024,  0.0128,  0.1432,  0.0746,
#          0.0949, -0.1233], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.103
# [1, 1150] loss: 2.271
# tensor([ 0.1042,  0.0984,  0.1766,  0.0418, -0.0079,  0.0130,  0.1359,  0.0787,
#          0.1041, -0.1272], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [1, 1160] loss: 2.275
# tensor([ 0.1005,  0.1068,  0.1785,  0.0466, -0.0138,  0.0091,  0.1328,  0.0811,
#          0.1081, -0.1324], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.103
# [1, 1170] loss: 2.302
# tensor([ 0.0991,  0.1087,  0.1828,  0.0523, -0.0181,  0.0043,  0.1304,  0.0822,
#          0.1087, -0.1337], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.103
# [1, 1180] loss: 2.272
# tensor([ 0.0947,  0.1076,  0.1878,  0.0515, -0.0211,  0.0111,  0.1318,  0.0814,
#          0.1084, -0.1377], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [1, 1190] loss: 2.274
# tensor([ 0.0924,  0.1110,  0.1863,  0.0568, -0.0261,  0.0132,  0.1341,  0.0818,
#          0.1088, -0.1431], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [1, 1200] loss: 2.292
# tensor([ 0.0870,  0.1217,  0.1861,  0.0576, -0.0320,  0.0140,  0.1356,  0.0811,
#          0.1083, -0.1446], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.103
# [1, 1210] loss: 2.339
# tensor([ 0.0872,  0.1268,  0.1863,  0.0535, -0.0345,  0.0147,  0.1368,  0.0828,
#          0.1036, -0.1426], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [1, 1220] loss: 2.293
# tensor([ 0.0916,  0.1277,  0.1854,  0.0518, -0.0353,  0.0109,  0.1358,  0.0790,
#          0.1057, -0.1374], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [1, 1230] loss: 2.310
# tensor([ 0.0949,  0.1265,  0.1834,  0.0538, -0.0339,  0.0078,  0.1308,  0.0750,
#          0.1128, -0.1356], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.103
# [1, 1240] loss: 2.275
# tensor([ 0.1020,  0.1258,  0.1789,  0.0607, -0.0374,  0.0047,  0.1243,  0.0771,
#          0.1175, -0.1379], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.103
# [1, 1250] loss: 2.290
# tensor([ 0.1028,  0.1221,  0.1797,  0.0671, -0.0427,  0.0014,  0.1309,  0.0768,
#          0.1195, -0.1426], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [1, 1260] loss: 2.269
# tensor([ 0.1083,  0.1162,  0.1760,  0.0701, -0.0486,  0.0010,  0.1366,  0.0736,
#          0.1250, -0.1434], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.103
# [1, 1270] loss: 2.330
# tensor([ 0.1156,  0.1101,  0.1703,  0.0667, -0.0508,  0.0007,  0.1341,  0.0783,
#          0.1340, -0.1445], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [1, 1280] loss: 2.278
# tensor([ 0.1156,  0.1119,  0.1638,  0.0677, -0.0481, -0.0010,  0.1318,  0.0771,
#          0.1427, -0.1470], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [1, 1290] loss: 2.290
# tensor([ 0.1123,  0.1154,  0.1571,  0.0702, -0.0467, -0.0056,  0.1356,  0.0722,
#          0.1534, -0.1498], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [1, 1300] loss: 2.339
# tensor([ 0.1104,  0.1173,  0.1539,  0.0711, -0.0468, -0.0014,  0.1364,  0.0661,
#          0.1548, -0.1473], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.097
# [1, 1310] loss: 2.376
# tensor([ 0.1088,  0.1177,  0.1488,  0.0670, -0.0456,  0.0051,  0.1328,  0.0692,
#          0.1547, -0.1436], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.097
# [1, 1320] loss: 2.346
# tensor([ 0.1083,  0.1132,  0.1426,  0.0611, -0.0379,  0.0071,  0.1307,  0.0741,
#          0.1504, -0.1335], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.097
# [1, 1330] loss: 2.349
# tensor([ 0.1077,  0.1070,  0.1360,  0.0547, -0.0385,  0.0097,  0.1286,  0.0792,
#          0.1546, -0.1224], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.097
# [1, 1340] loss: 2.322
# tensor([ 0.1048,  0.1069,  0.1326,  0.0480, -0.0346,  0.0121,  0.1248,  0.0771,
#          0.1537, -0.1082], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.097
# [1, 1350] loss: 2.299
# tensor([ 0.1018,  0.1111,  0.1430,  0.0412, -0.0344,  0.0089,  0.1207,  0.0719,
#          0.1518, -0.0995], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.097
# [1, 1360] loss: 2.291
# tensor([ 0.1038,  0.1157,  0.1433,  0.0384, -0.0367,  0.0050,  0.1215,  0.0657,
#          0.1546, -0.0947], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.097
# [1, 1370] loss: 2.287
# tensor([ 0.1069,  0.1316,  0.1426,  0.0336, -0.0416,  0.0027,  0.1171,  0.0590,
#          0.1551, -0.0911], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [1, 1380] loss: 2.320
# tensor([ 0.1113,  0.1366,  0.1442,  0.0275, -0.0408, -0.0022,  0.1145,  0.0594,
#          0.1523, -0.0871], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.097
# [1, 1390] loss: 2.318
# tensor([ 0.1154,  0.1353,  0.1481,  0.0255, -0.0421, -0.0080,  0.1097,  0.0601,
#          0.1485, -0.0770], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.103
# [1, 1400] loss: 2.293
# tensor([ 0.1172,  0.1302,  0.1543,  0.0205, -0.0430, -0.0097,  0.1073,  0.0572,
#          0.1517, -0.0711], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [1, 1410] loss: 2.313
# tensor([ 0.1135,  0.1311,  0.1557,  0.0143, -0.0437, -0.0071,  0.1068,  0.0542,
#          0.1553, -0.0663], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [1, 1420] loss: 2.308
# tensor([ 0.1134,  0.1312,  0.1575,  0.0118, -0.0456, -0.0088,  0.1020,  0.0552,
#          0.1550, -0.0583], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.103
# [1, 1430] loss: 2.315
# tensor([ 0.1160,  0.1377,  0.1539,  0.0160, -0.0464, -0.0134,  0.1012,  0.0543,
#          0.1503, -0.0558], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [1, 1440] loss: 2.288
# tensor([ 0.1142,  0.1449,  0.1482,  0.0224, -0.0480, -0.0191,  0.1036,  0.0508,
#          0.1499, -0.0528], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.097
# [1, 1450] loss: 2.292
# tensor([ 0.1153,  0.1448,  0.1467,  0.0234, -0.0480, -0.0251,  0.1017,  0.0452,
#          0.1549, -0.0452], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.097
# [1, 1460] loss: 2.364
# tensor([ 0.1117,  0.1401,  0.1490,  0.0254, -0.0439, -0.0258,  0.0995,  0.0417,
#          0.1555, -0.0396], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [1, 1470] loss: 2.271
# tensor([ 0.1155,  0.1339,  0.1483,  0.0217, -0.0331, -0.0267,  0.0976,  0.0377,
#          0.1579, -0.0395], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.097
# [1, 1480] loss: 2.312
# tensor([ 0.1174,  0.1270,  0.1512,  0.0160, -0.0303, -0.0275,  0.0978,  0.0319,
#          0.1630, -0.0342], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.097
# [1, 1490] loss: 2.312
# tensor([ 0.1225,  0.1200,  0.1536,  0.0159, -0.0289, -0.0310,  0.0984,  0.0295,
#          0.1631, -0.0312], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.097
# [1, 1500] loss: 2.334
# tensor([ 0.1219,  0.1173,  0.1532,  0.0165, -0.0231, -0.0362,  0.0977,  0.0248,
#          0.1625, -0.0231], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.097
# [1, 1510] loss: 2.333
# tensor([ 0.1205,  0.1199,  0.1494,  0.0239, -0.0219, -0.0344,  0.0929,  0.0231,
#          0.1579, -0.0193], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [1, 1520] loss: 2.282
# tensor([ 0.1219,  0.1186,  0.1436,  0.0294, -0.0208, -0.0322,  0.0933,  0.0229,
#          0.1576, -0.0220], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [1, 1530] loss: 2.307
# tensor([ 0.1290,  0.1160,  0.1421,  0.0358, -0.0204, -0.0354,  0.0911,  0.0216,
#          0.1554, -0.0228], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.097
# [1, 1540] loss: 2.323
# tensor([ 0.1341,  0.1105,  0.1421,  0.0429, -0.0212, -0.0363,  0.0899,  0.0227,
#          0.1501, -0.0225], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [1, 1550] loss: 2.329
# tensor([ 0.1372,  0.1079,  0.1401,  0.0448, -0.0236, -0.0257,  0.0851,  0.0253,
#          0.1467, -0.0251], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [1, 1560] loss: 2.301
# tensor([ 0.1386,  0.1029,  0.1456,  0.0456, -0.0189, -0.0232,  0.0788,  0.0244,
#          0.1421, -0.0238], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.103
# [1, 1570] loss: 2.311
# tensor([ 0.1393,  0.0997,  0.1487,  0.0471, -0.0062, -0.0240,  0.0727,  0.0197,
#          0.1403, -0.0260], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [1, 1580] loss: 2.298
# tensor([ 0.1397,  0.0996,  0.1492,  0.0442, -0.0019, -0.0263,  0.0698,  0.0241,
#          0.1392, -0.0265], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [1, 1590] loss: 2.285
# tensor([ 0.1378,  0.1051,  0.1542,  0.0432, -0.0033, -0.0293,  0.0642,  0.0245,
#          0.1404, -0.0265], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [1, 1600] loss: 2.254
# tensor([ 0.1366,  0.1118,  0.1588,  0.0385, -0.0078, -0.0318,  0.0646,  0.0231,
#          0.1419, -0.0259], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [1, 1610] loss: 2.313
# tensor([ 0.1380,  0.1219,  0.1634,  0.0344, -0.0101, -0.0335,  0.0624,  0.0199,
#          0.1387, -0.0262], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.103
# [1, 1620] loss: 2.297
# tensor([ 0.1380,  0.1279,  0.1623,  0.0312, -0.0066, -0.0341,  0.0570,  0.0258,
#          0.1368, -0.0294], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.103
# [1, 1630] loss: 2.336
# tensor([ 0.1401,  0.1256,  0.1603,  0.0281,  0.0024, -0.0367,  0.0512,  0.0347,
#          0.1333, -0.0304], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.103
# [1, 1640] loss: 2.298
# tensor([ 0.1389,  0.1237,  0.1563,  0.0280,  0.0080, -0.0417,  0.0526,  0.0452,
#          0.1305, -0.0326], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [1, 1650] loss: 2.330
# tensor([ 0.1355,  0.1263,  0.1533,  0.0305,  0.0068, -0.0475,  0.0491,  0.0504,
#          0.1300, -0.0255], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [1, 1660] loss: 2.293
# tensor([ 0.1310,  0.1277,  0.1524,  0.0343,  0.0125, -0.0536,  0.0462,  0.0478,
#          0.1294, -0.0193], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [1, 1670] loss: 2.291
# tensor([ 0.1279,  0.1300,  0.1550,  0.0319,  0.0185, -0.0598,  0.0457,  0.0456,
#          0.1295, -0.0166], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.103
# [1, 1680] loss: 2.282
# tensor([ 0.1223,  0.1346,  0.1592,  0.0266,  0.0227, -0.0647,  0.0423,  0.0548,
#          0.1280, -0.0189], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.103
# [1, 1690] loss: 2.334
# tensor([ 0.1200,  0.1360,  0.1608,  0.0204,  0.0212, -0.0672,  0.0403,  0.0584,
#          0.1260, -0.0101], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.103
# [1, 1700] loss: 2.292
# tensor([ 0.1182,  0.1403,  0.1569,  0.0210,  0.0202, -0.0675,  0.0373,  0.0596,
#          0.1238, -0.0038], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.103
# [1, 1710] loss: 2.299
# tensor([ 0.1161,  0.1410,  0.1551,  0.0228,  0.0158, -0.0717,  0.0350,  0.0632,
#          0.1258,  0.0024], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [1, 1720] loss: 2.333
# tensor([ 0.1175,  0.1442,  0.1500,  0.0308,  0.0107, -0.0719,  0.0322,  0.0612,
#          0.1256,  0.0052], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [1, 1730] loss: 2.293
# tensor([ 0.1211,  0.1450,  0.1455,  0.0315,  0.0123, -0.0721,  0.0342,  0.0609,
#          0.1210,  0.0064], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [1, 1740] loss: 2.283
# tensor([ 0.1227,  0.1443,  0.1424,  0.0274,  0.0116, -0.0761,  0.0343,  0.0676,
#          0.1204,  0.0109], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 1750] loss: 2.279
# tensor([ 0.1199,  0.1485,  0.1440,  0.0216,  0.0099, -0.0816,  0.0336,  0.0671,
#          0.1266,  0.0148], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.114
# [1, 1760] loss: 2.314
# tensor([ 0.1215,  0.1463,  0.1442,  0.0226,  0.0089, -0.0823,  0.0344,  0.0653,
#          0.1290,  0.0146], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 1770] loss: 2.316
# tensor([ 0.1177,  0.1487,  0.1403,  0.0248,  0.0076, -0.0812,  0.0301,  0.0672,
#          0.1326,  0.0164], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 1780] loss: 2.310
# tensor([ 0.1159,  0.1479,  0.1344,  0.0241,  0.0055, -0.0815,  0.0289,  0.0669,
#          0.1369,  0.0248], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.114
# [1, 1790] loss: 2.297
# tensor([ 0.1137,  0.1477,  0.1301,  0.0211,  0.0078, -0.0823,  0.0331,  0.0661,
#          0.1359,  0.0306], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 1800] loss: 2.317
# tensor([ 0.1127,  0.1493,  0.1294,  0.0158,  0.0085, -0.0776,  0.0345,  0.0714,
#          0.1310,  0.0291], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 1810] loss: 2.310
# tensor([ 0.1175,  0.1516,  0.1286,  0.0194,  0.0052, -0.0784,  0.0389,  0.0726,
#          0.1247,  0.0245], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 1820] loss: 2.322
# tensor([ 0.1158,  0.1504,  0.1272,  0.0352,  0.0034, -0.0814,  0.0415,  0.0686,
#          0.1180,  0.0261], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 1830] loss: 2.255
# tensor([ 0.1196,  0.1541,  0.1301,  0.0389, -0.0004, -0.0795,  0.0380,  0.0628,
#          0.1129,  0.0279], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 1840] loss: 2.288
# tensor([ 0.1306,  0.1571,  0.1350,  0.0359, -0.0059, -0.0812,  0.0365,  0.0564,
#          0.1091,  0.0297], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 1850] loss: 2.283
# tensor([ 0.1394,  0.1572,  0.1388,  0.0323, -0.0084, -0.0819,  0.0347,  0.0552,
#          0.1055,  0.0295], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 1860] loss: 2.299
# tensor([ 0.1397,  0.1616,  0.1356,  0.0329, -0.0125, -0.0837,  0.0361,  0.0579,
#          0.1092,  0.0253], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.114
# [1, 1870] loss: 2.314
# tensor([ 0.1413,  0.1648,  0.1300,  0.0342, -0.0168, -0.0854,  0.0441,  0.0566,
#          0.1112,  0.0224], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.114
# [1, 1880] loss: 2.291
# tensor([ 0.1422,  0.1672,  0.1270,  0.0309, -0.0192, -0.0818,  0.0439,  0.0658,
#          0.1077,  0.0190], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 1890] loss: 2.311
# tensor([ 0.1411,  0.1728,  0.1229,  0.0293, -0.0175, -0.0802,  0.0394,  0.0705,
#          0.1019,  0.0219], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.114
# [1, 1900] loss: 2.269
# tensor([ 0.1436,  0.1767,  0.1250,  0.0288, -0.0156, -0.0787,  0.0333,  0.0678,
#          0.0972,  0.0233], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 1910] loss: 2.339
# tensor([ 0.1478,  0.1742,  0.1349,  0.0243, -0.0171, -0.0718,  0.0267,  0.0624,
#          0.0936,  0.0255], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.114
# [1, 1920] loss: 2.297
# tensor([ 0.1477,  0.1713,  0.1409,  0.0208, -0.0180, -0.0678,  0.0232,  0.0606,
#          0.0967,  0.0249], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.114
# [1, 1930] loss: 2.277
# tensor([ 0.1468,  0.1684,  0.1480,  0.0233, -0.0180, -0.0678,  0.0208,  0.0555,
#          0.0974,  0.0252], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 1940] loss: 2.278
# tensor([ 0.1461,  0.1741,  0.1487,  0.0229, -0.0156, -0.0718,  0.0182,  0.0512,
#          0.0974,  0.0277], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 1950] loss: 2.290
# tensor([ 0.1457,  0.1806,  0.1486,  0.0213, -0.0133, -0.0754,  0.0128,  0.0479,
#          0.1011,  0.0283], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.114
# [1, 1960] loss: 2.314
# tensor([ 0.1453,  0.1854,  0.1440,  0.0254, -0.0064, -0.0779,  0.0072,  0.0424,
#          0.1016,  0.0301], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 1970] loss: 2.294
# tensor([ 0.1450,  0.1851,  0.1391,  0.0260, -0.0039, -0.0795,  0.0048,  0.0361,
#          0.1099,  0.0340], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 1980] loss: 2.303
# tensor([ 0.1440,  0.1852,  0.1433,  0.0252, -0.0071, -0.0775, -0.0005,  0.0366,
#          0.1098,  0.0371], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 1990] loss: 2.320
# tensor([ 0.1396,  0.1854,  0.1433,  0.0283, -0.0124, -0.0769, -0.0038,  0.0382,
#          0.1110,  0.0428], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.114
# [1, 2000] loss: 2.288
# tensor([ 0.1335,  0.1863,  0.1425,  0.0349, -0.0142, -0.0761, -0.0077,  0.0389,
#          0.1097,  0.0475], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 2010] loss: 2.277
# tensor([ 0.1268,  0.1912,  0.1449,  0.0408, -0.0142, -0.0798, -0.0115,  0.0412,
#          0.1060,  0.0492], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 2020] loss: 2.325
# tensor([ 0.1199,  0.1900,  0.1516,  0.0452, -0.0124, -0.0844, -0.0144,  0.0406,
#          0.1076,  0.0501], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 2030] loss: 2.295
# tensor([ 0.1130,  0.1913,  0.1538,  0.0451, -0.0062, -0.0842, -0.0119,  0.0374,
#          0.1085,  0.0472], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 2040] loss: 2.292
# tensor([ 0.1091,  0.1910,  0.1586,  0.0452, -0.0033, -0.0854, -0.0119,  0.0351,
#          0.1080,  0.0472], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 2050] loss: 2.319
# tensor([ 0.1088,  0.1921,  0.1565,  0.0452,  0.0021, -0.0899, -0.0136,  0.0370,
#          0.1056,  0.0492], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.114
# [1, 2060] loss: 2.289
# tensor([ 0.1082,  0.1880,  0.1564,  0.0409,  0.0104, -0.0948, -0.0144,  0.0387,
#          0.1054,  0.0538], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 2070] loss: 2.327
# tensor([ 0.1037,  0.1819,  0.1591,  0.0447,  0.0129, -0.0958, -0.0147,  0.0377,
#          0.1103,  0.0528], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 2080] loss: 2.296
# tensor([ 0.0977,  0.1833,  0.1555,  0.0500,  0.0140, -0.0937, -0.0182,  0.0363,
#          0.1163,  0.0514], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 2090] loss: 2.331
# tensor([ 0.0951,  0.1833,  0.1497,  0.0515,  0.0139, -0.0899, -0.0239,  0.0414,
#          0.1180,  0.0533], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.114
# [1, 2100] loss: 2.332
# tensor([ 0.0900,  0.1787,  0.1431,  0.0521,  0.0154, -0.0844, -0.0235,  0.0415,
#          0.1243,  0.0560], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 2110] loss: 2.313
# tensor([ 0.0956,  0.1767,  0.1363,  0.0479,  0.0160, -0.0816, -0.0224,  0.0424,
#          0.1247,  0.0579], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 2120] loss: 2.306
# tensor([ 0.1026,  0.1754,  0.1306,  0.0467,  0.0128, -0.0757, -0.0208,  0.0420,
#          0.1225,  0.0580], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 2130] loss: 2.332
# tensor([ 0.1007,  0.1774,  0.1311,  0.0497,  0.0118, -0.0748, -0.0148,  0.0399,
#          0.1193,  0.0545], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 2140] loss: 2.290
# tensor([ 0.0956,  0.1785,  0.1306,  0.0485,  0.0117, -0.0729, -0.0094,  0.0369,
#          0.1189,  0.0566], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 2150] loss: 2.281
# tensor([ 0.0953,  0.1854,  0.1287,  0.0469,  0.0112, -0.0727, -0.0092,  0.0343,
#          0.1175,  0.0570], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.114
# [1, 2160] loss: 2.277
# tensor([ 0.1042,  0.1867,  0.1295,  0.0482,  0.0069, -0.0739, -0.0128,  0.0340,
#          0.1125,  0.0587], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 2170] loss: 2.375
# tensor([ 0.1089,  0.1885,  0.1255,  0.0501,  0.0012, -0.0708, -0.0074,  0.0331,
#          0.1062,  0.0589], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.114
# [1, 2180] loss: 2.312
# tensor([ 0.1126,  0.1857,  0.1196,  0.0476, -0.0050, -0.0598, -0.0009,  0.0357,
#          0.1033,  0.0566], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.114
# [1, 2190] loss: 2.343
# tensor([ 0.1117,  0.1830,  0.1131,  0.0491, -0.0113, -0.0519,  0.0073,  0.0415,
#          0.0983,  0.0558], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 2200] loss: 2.291
# tensor([ 0.1102,  0.1774,  0.1150,  0.0492, -0.0176, -0.0429,  0.0119,  0.0425,
#          0.0964,  0.0550], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 2210] loss: 2.314
# tensor([ 0.1131,  0.1821,  0.1183,  0.0475, -0.0240, -0.0329,  0.0091,  0.0386,
#          0.0913,  0.0536], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 2220] loss: 2.271
# tensor([ 0.1231,  0.1808,  0.1214,  0.0425, -0.0268, -0.0214,  0.0038,  0.0328,
#          0.0877,  0.0518], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 2230] loss: 2.322
# tensor([ 0.1228,  0.1791,  0.1275,  0.0411, -0.0309, -0.0148, -0.0018,  0.0307,
#          0.0887,  0.0525], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 2240] loss: 2.260
# tensor([ 0.1182,  0.1793,  0.1317,  0.0405, -0.0333, -0.0144, -0.0041,  0.0258,
#          0.0923,  0.0583], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 2250] loss: 2.258
# tensor([ 0.1183,  0.1782,  0.1489,  0.0401, -0.0369, -0.0184, -0.0093,  0.0234,
#          0.0893,  0.0590], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 2260] loss: 2.314
# tensor([ 0.1226,  0.1767,  0.1592,  0.0400, -0.0371, -0.0232, -0.0118,  0.0191,
#          0.0838,  0.0618], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 2270] loss: 2.242
# tensor([ 0.1247,  0.1753,  0.1707,  0.0359, -0.0374, -0.0252, -0.0160,  0.0152,
#          0.0817,  0.0648], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 2280] loss: 2.267
# tensor([ 0.1289,  0.1821,  0.1734,  0.0302, -0.0398, -0.0300, -0.0219,  0.0158,
#          0.0779,  0.0712], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 2290] loss: 2.316
# tensor([ 0.1317,  0.1854,  0.1719,  0.0251, -0.0420, -0.0325, -0.0209,  0.0201,
#          0.0770,  0.0717], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 2300] loss: 2.337
# tensor([ 0.1281,  0.1875,  0.1700,  0.0222, -0.0430, -0.0292, -0.0188,  0.0206,
#          0.0826,  0.0677], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.114
# [1, 2310] loss: 2.334
# tensor([ 0.1261,  0.1855,  0.1677,  0.0201, -0.0468, -0.0222, -0.0171,  0.0287,
#          0.0844,  0.0621], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.114
# [1, 2320] loss: 2.297
# tensor([ 0.1256,  0.1802,  0.1629,  0.0210, -0.0483, -0.0142, -0.0208,  0.0309,
#          0.0859,  0.0654], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.114
# [1, 2330] loss: 2.301
# tensor([ 0.1328,  0.1762,  0.1602,  0.0272, -0.0504, -0.0155, -0.0231,  0.0281,
#          0.0863,  0.0666], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 2340] loss: 2.291
# tensor([ 0.1357,  0.1730,  0.1579,  0.0322, -0.0502, -0.0201, -0.0269,  0.0298,
#          0.0910,  0.0658], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.114
# [1, 2350] loss: 2.300
# tensor([ 0.1344,  0.1701,  0.1588,  0.0318, -0.0477, -0.0206, -0.0325,  0.0336,
#          0.0959,  0.0644], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 2360] loss: 2.348
# tensor([ 0.1314,  0.1687,  0.1592,  0.0299, -0.0422, -0.0212, -0.0339,  0.0332,
#          0.1011,  0.0620], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.114
# [1, 2370] loss: 2.303
# tensor([ 0.1292,  0.1665,  0.1584,  0.0291, -0.0348, -0.0236, -0.0317,  0.0326,
#          0.0996,  0.0634], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.114
# [1, 2380] loss: 2.319
# tensor([ 0.1290,  0.1685,  0.1565,  0.0284, -0.0311, -0.0259, -0.0295,  0.0328,
#          0.0946,  0.0656], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.114
# [1, 2390] loss: 2.279
# tensor([ 0.1244,  0.1707,  0.1513,  0.0307, -0.0228, -0.0309, -0.0318,  0.0371,
#          0.0950,  0.0654], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 2400] loss: 2.297
# tensor([ 0.1205,  0.1788,  0.1466,  0.0301, -0.0192, -0.0311, -0.0369,  0.0412,
#          0.0976,  0.0611], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 2410] loss: 2.302
# tensor([ 0.1167,  0.1822,  0.1483,  0.0279, -0.0134, -0.0319, -0.0423,  0.0408,
#          0.1044,  0.0554], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.114
# [1, 2420] loss: 2.318
# tensor([ 0.1148,  0.1849,  0.1473,  0.0249, -0.0140, -0.0282, -0.0437,  0.0446,
#          0.1060,  0.0514], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.114
# [1, 2430] loss: 2.273
# tensor([ 0.1160,  0.1865,  0.1442,  0.0196, -0.0184, -0.0301, -0.0377,  0.0526,
#          0.1076,  0.0478], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 2440] loss: 2.293
# tensor([ 0.1177,  0.1860,  0.1451,  0.0176, -0.0208, -0.0309, -0.0372,  0.0555,
#          0.1071,  0.0479], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.114
# [1, 2450] loss: 2.343
# tensor([ 0.1232,  0.1820,  0.1409,  0.0168, -0.0143, -0.0311, -0.0413,  0.0588,
#          0.1064,  0.0467], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.114
# [1, 2460] loss: 2.314
# tensor([ 0.1206,  0.1759,  0.1434,  0.0183, -0.0099, -0.0331, -0.0423,  0.0609,
#          0.1083,  0.0461], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.114
# [1, 2470] loss: 2.323
# tensor([ 0.1178,  0.1691,  0.1444,  0.0198, -0.0068, -0.0250, -0.0469,  0.0644,
#          0.1045,  0.0469], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.114
# [1, 2480] loss: 2.334
# tensor([ 0.1139,  0.1621,  0.1437,  0.0215, -0.0005, -0.0226, -0.0470,  0.0665,
#          0.1016,  0.0496], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.114
# [1, 2490] loss: 2.278
# tensor([ 0.1115,  0.1587,  0.1457,  0.0227,  0.0014, -0.0240, -0.0476,  0.0658,
#          0.1031,  0.0515], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.114
# [1, 2500] loss: 2.275
# ...
# Validation Accuracy: 0.103
# [3, 5420] loss: 2.270
# tensor([-0.0679,  0.0531,  0.1244,  0.0711,  0.0199,  0.0068,  0.0264,  0.0328,
#          0.0292, -0.0674], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [3, 5430] loss: 2.324
# tensor([-0.0647,  0.0480,  0.1241,  0.0734,  0.0178,  0.0048,  0.0259,  0.0335,
#          0.0358, -0.0705], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [3, 5440] loss: 2.314
# tensor([-0.0647,  0.0418,  0.1220,  0.0763,  0.0152,  0.0003,  0.0214,  0.0408,
#          0.0386, -0.0635], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [3, 5450] loss: 2.320
# tensor([-0.0675,  0.0429,  0.1204,  0.0748,  0.0194, -0.0020,  0.0154,  0.0423,
#          0.0393, -0.0567], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.103
# [3, 5460] loss: 2.304
# tensor([-0.0694,  0.0494,  0.1190,  0.0729,  0.0235,  0.0009,  0.0090,  0.0385,
#          0.0354, -0.0506], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [3, 5470] loss: 2.286
# tensor([-0.0743,  0.0583,  0.1190,  0.0707,  0.0235,  0.0024,  0.0068,  0.0340,
#          0.0326, -0.0448], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [3, 5480] loss: 2.300
# tensor([-0.0768,  0.0617,  0.1229,  0.0722,  0.0192,  0.0006,  0.0017,  0.0342,
#          0.0329, -0.0408], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [3, 5490] loss: 2.292
# tensor([-0.0806,  0.0594,  0.1249,  0.0725,  0.0186,  0.0021, -0.0012,  0.0355,
#          0.0360, -0.0399], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.103
# [3, 5500] loss: 2.303
# tensor([-0.0861,  0.0617,  0.1213,  0.0681,  0.0175,  0.0059, -0.0053,  0.0388,
#          0.0479, -0.0431], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.103
# [3, 5510] loss: 2.303
# tensor([-0.0852,  0.0627,  0.1218,  0.0621,  0.0127,  0.0142, -0.0111,  0.0370,
#          0.0549, -0.0427], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [3, 5520] loss: 2.298
# tensor([-0.0824,  0.0673,  0.1235,  0.0593,  0.0086,  0.0158, -0.0129,  0.0339,
#          0.0574, -0.0442], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.103
# [3, 5530] loss: 2.321
# tensor([-0.0853,  0.0707,  0.1195,  0.0575,  0.0092,  0.0136, -0.0102,  0.0406,
#          0.0557, -0.0453], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.103
# [3, 5540] loss: 2.313
# tensor([-0.0815,  0.0771,  0.1135,  0.0602,  0.0063,  0.0085, -0.0079,  0.0417,
#          0.0544, -0.0461], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.103
# [3, 5550] loss: 2.307
# tensor([-0.0795,  0.0764,  0.1106,  0.0587,  0.0047,  0.0070, -0.0037,  0.0432,
#          0.0526, -0.0434], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [3, 5560] loss: 2.291
# tensor([-0.0829,  0.0814,  0.1055,  0.0580,  0.0036,  0.0082, -0.0018,  0.0461,
#          0.0515, -0.0432], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.103
# [3, 5570] loss: 2.279
# tensor([-0.0863,  0.0843,  0.1055,  0.0564,  0.0037,  0.0112, -0.0046,  0.0498,
#          0.0532, -0.0474], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [3, 5580] loss: 2.289
# tensor([-0.0890,  0.0872,  0.1030,  0.0582,  0.0066,  0.0079, -0.0057,  0.0532,
#          0.0560, -0.0523], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.103
# [3, 5590] loss: 2.298
# tensor([-0.0933,  0.0866,  0.1072,  0.0614,  0.0051,  0.0060, -0.0069,  0.0541,
#          0.0589, -0.0544], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [3, 5600] loss: 2.299
# tensor([-0.0943,  0.0819,  0.1136,  0.0626,  0.0003,  0.0060, -0.0104,  0.0557,
#          0.0599, -0.0512], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [3, 5610] loss: 2.307
# tensor([-9.4885e-02,  7.5790e-02,  1.1691e-01,  6.1710e-02, -5.2634e-05,
#          5.4506e-03, -9.1630e-03,  6.0104e-02,  5.7930e-02, -4.9858e-02],
#        grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [3, 5620] loss: 2.281
# tensor([-0.0963,  0.0734,  0.1138,  0.0619,  0.0028,  0.0018, -0.0109,  0.0707,
#          0.0546, -0.0481], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.103
# [3, 5630] loss: 2.301
# tensor([-0.0992,  0.0759,  0.1145,  0.0587, -0.0003, -0.0025, -0.0046,  0.0804,
#          0.0515, -0.0517], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.103
# [3, 5640] loss: 2.343
# tensor([-0.0959,  0.0772,  0.1121,  0.0595,  0.0024, -0.0015, -0.0047,  0.0794,
#          0.0460, -0.0513], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.103
# [3, 5650] loss: 2.306
# tensor([-0.0918,  0.0769,  0.1133,  0.0599, -0.0002, -0.0003, -0.0083,  0.0776,
#          0.0440, -0.0477], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.103
# [3, 5660] loss: 2.333
# tensor([-0.0826,  0.0729,  0.1156,  0.0612, -0.0055, -0.0003, -0.0024,  0.0738,
#          0.0389, -0.0475], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [3, 5670] loss: 2.296
# tensor([-0.0779,  0.0693,  0.1185,  0.0612, -0.0072, -0.0041,  0.0003,  0.0680,
#          0.0419, -0.0457], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [3, 5680] loss: 2.296
# tensor([-0.0689,  0.0678,  0.1217,  0.0613, -0.0048, -0.0097, -0.0025,  0.0615,
#          0.0472, -0.0493], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [3, 5690] loss: 2.323
# tensor([-0.0642,  0.0671,  0.1209,  0.0612,  0.0034, -0.0132, -0.0033,  0.0589,
#          0.0483, -0.0547], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [3, 5700] loss: 2.332
# tensor([-0.0612,  0.0687,  0.1161,  0.0566,  0.0169, -0.0170, -0.0080,  0.0538,
#          0.0525, -0.0539], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [3, 5710] loss: 2.318
# tensor([-0.0534,  0.0648,  0.1098,  0.0529,  0.0271, -0.0227, -0.0100,  0.0516,
#          0.0560, -0.0512], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.103
# [3, 5720] loss: 2.305
# tensor([-0.0485,  0.0619,  0.1031,  0.0491,  0.0374, -0.0271, -0.0144,  0.0514,
#          0.0595, -0.0474], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [3, 5730] loss: 2.286
# tensor([-0.0510,  0.0663,  0.0991,  0.0496,  0.0422, -0.0302, -0.0148,  0.0508,
#          0.0611, -0.0483], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [3, 5740] loss: 2.317
# tensor([-0.0541,  0.0668,  0.0993,  0.0478,  0.0440, -0.0332, -0.0017,  0.0462,
#          0.0610, -0.0515], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.103
# [3, 5750] loss: 2.327
# tensor([-0.0529,  0.0634,  0.0984,  0.0427,  0.0470, -0.0303,  0.0021,  0.0402,
#          0.0654, -0.0512], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [3, 5760] loss: 2.303
# tensor([-0.0469,  0.0590,  0.0936,  0.0365,  0.0458, -0.0288,  0.0070,  0.0368,
#          0.0751, -0.0532], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [3, 5770] loss: 2.305
# tensor([-0.0379,  0.0603,  0.0933,  0.0340,  0.0409, -0.0271,  0.0052,  0.0362,
#          0.0779, -0.0580], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [3, 5780] loss: 2.310
# tensor([-0.0309,  0.0564,  0.0945,  0.0309,  0.0349, -0.0192,  0.0047,  0.0408,
#          0.0766, -0.0639], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.103
# [3, 5790] loss: 2.309
# tensor([-0.0291,  0.0518,  0.0947,  0.0353,  0.0324, -0.0173,  0.0025,  0.0418,
#          0.0806, -0.0683], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [3, 5800] loss: 2.288
# tensor([-0.0289,  0.0528,  0.0971,  0.0337,  0.0275, -0.0177,  0.0030,  0.0405,
#          0.0791, -0.0625], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [3, 5810] loss: 2.294
# tensor([-0.0282,  0.0567,  0.1011,  0.0331,  0.0241, -0.0208,  0.0036,  0.0418,
#          0.0771, -0.0644], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.103
# [3, 5820] loss: 2.279
# tensor([-0.0281,  0.0546,  0.1062,  0.0284,  0.0233, -0.0262,  0.0047,  0.0504,
#          0.0794, -0.0692], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.103
# [3, 5830] loss: 2.314
# tensor([-0.0227,  0.0541,  0.1107,  0.0224,  0.0199, -0.0317,  0.0087,  0.0540,
#          0.0779, -0.0705], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [3, 5840] loss: 2.295
# tensor([-0.0173,  0.0577,  0.1077,  0.0203,  0.0162, -0.0328,  0.0087,  0.0583,
#          0.0786, -0.0751], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.103
# [3, 5850] loss: 2.304
# tensor([-0.0166,  0.0587,  0.1078,  0.0269,  0.0150, -0.0286,  0.0064,  0.0562,
#          0.0772, -0.0809], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [3, 5860] loss: 2.304
# tensor([-0.0117,  0.0547,  0.1093,  0.0280,  0.0214, -0.0267,  0.0045,  0.0551,
#          0.0745, -0.0871], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [3, 5870] loss: 2.320
# tensor([-0.0071,  0.0488,  0.1098,  0.0266,  0.0236, -0.0265,  0.0007,  0.0540,
#          0.0777, -0.0857], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [3, 5880] loss: 2.320
# tensor([-0.0035,  0.0466,  0.1065,  0.0217,  0.0254, -0.0222, -0.0026,  0.0538,
#          0.0762, -0.0796], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.103
# [3, 5890] loss: 2.300
# tensor([ 0.0032,  0.0465,  0.1083,  0.0162,  0.0250, -0.0175, -0.0015,  0.0517,
#          0.0712, -0.0807], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.103
# [3, 5900] loss: 2.280
# tensor([ 0.0058,  0.0456,  0.1047,  0.0137,  0.0249, -0.0166, -0.0016,  0.0593,
#          0.0714, -0.0852], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.103
# [3, 5910] loss: 2.329
# tensor([ 0.0031,  0.0454,  0.0988,  0.0084,  0.0228, -0.0184, -0.0041,  0.0684,
#          0.0767, -0.0793], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.103
# [3, 5920] loss: 2.304
# tensor([ 0.0016,  0.0516,  0.0923,  0.0067,  0.0238, -0.0234, -0.0013,  0.0689,
#          0.0776, -0.0759], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.103
# [3, 5930] loss: 2.303
# tensor([-0.0009,  0.0514,  0.0854,  0.0093,  0.0219, -0.0251,  0.0021,  0.0711,
#          0.0804, -0.0736], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.103
# [3, 5940] loss: 2.314
# tensor([-0.0005,  0.0500,  0.0828,  0.0070,  0.0194, -0.0285,  0.0085,  0.0719,
#          0.0848, -0.0738], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.097
# [3, 5950] loss: 2.302
# tensor([-0.0037,  0.0500,  0.0791,  0.0019,  0.0183, -0.0307,  0.0104,  0.0723,
#          0.0921, -0.0684], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [3, 5960] loss: 2.319
# tensor([-0.0047,  0.0462,  0.0758, -0.0013,  0.0189, -0.0321,  0.0108,  0.0719,
#          0.0948, -0.0586], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.097
# [3, 5970] loss: 2.323
# tensor([-0.0025,  0.0416,  0.0702,  0.0030,  0.0191, -0.0269,  0.0082,  0.0673,
#          0.0983, -0.0564], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.097
# [3, 5980] loss: 2.317
# tensor([-0.0041,  0.0387,  0.0655,  0.0063,  0.0185, -0.0171,  0.0057,  0.0625,
#          0.1013, -0.0552], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.097
# [3, 5990] loss: 2.283
# tensor([-0.0089,  0.0432,  0.0697,  0.0064,  0.0139, -0.0126,  0.0022,  0.0612,
#          0.1004, -0.0533], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.097
# [3, 6000] loss: 2.316
# tensor([-0.0098,  0.0434,  0.0717,  0.0072,  0.0108, -0.0153,  0.0040,  0.0628,
#          0.0987, -0.0512], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [3, 6010] loss: 2.317
# tensor([ 0.0004,  0.0391,  0.0679,  0.0122,  0.0101, -0.0206,  0.0045,  0.0604,
#          0.0966, -0.0483], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.097
# [3, 6020] loss: 2.312
# tensor([ 0.0118,  0.0412,  0.0658,  0.0130,  0.0103, -0.0254,  0.0020,  0.0624,
#          0.0913, -0.0505], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [3, 6030] loss: 2.305
# tensor([ 0.0186,  0.0425,  0.0619,  0.0128,  0.0163, -0.0281, -0.0001,  0.0587,
#          0.0890, -0.0493], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.097
# [3, 6040] loss: 2.312
# tensor([ 0.0173,  0.0408,  0.0639,  0.0102,  0.0205, -0.0298,  0.0047,  0.0585,
#          0.0839, -0.0477], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.097
# [3, 6050] loss: 2.316
# tensor([ 0.0242,  0.0378,  0.0602,  0.0129,  0.0199, -0.0263,  0.0046,  0.0614,
#          0.0777, -0.0501], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.097
# [3, 6060] loss: 2.288
# tensor([ 0.0229,  0.0364,  0.0562,  0.0176,  0.0190, -0.0195,  0.0023,  0.0680,
#          0.0744, -0.0551], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.097
# [3, 6070] loss: 2.307
# tensor([ 0.0209,  0.0384,  0.0563,  0.0151,  0.0162, -0.0125, -0.0021,  0.0684,
#          0.0808, -0.0597], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.097
# [3, 6080] loss: 2.293
# tensor([ 0.0181,  0.0368,  0.0554,  0.0098,  0.0134, -0.0094,  0.0068,  0.0641,
#          0.0886, -0.0623], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.097
# [3, 6090] loss: 2.318
# tensor([ 0.0196,  0.0318,  0.0523,  0.0043,  0.0099, -0.0078,  0.0231,  0.0582,
#          0.0930, -0.0634], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.097
# [3, 6100] loss: 2.290
# tensor([ 0.0170,  0.0292,  0.0487,  0.0050,  0.0136, -0.0034,  0.0300,  0.0535,
#          0.0947, -0.0674], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.097
# [3, 6110] loss: 2.302
# tensor([ 0.0118,  0.0247,  0.0580,  0.0078,  0.0170, -0.0058,  0.0314,  0.0499,
#          0.0978, -0.0722], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.097
# [3, 6120] loss: 2.313
# tensor([ 0.0057,  0.0251,  0.0570,  0.0075,  0.0235, -0.0066,  0.0322,  0.0449,
#          0.1009, -0.0699], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.097
# [3, 6130] loss: 2.290
# tensor([-0.0007,  0.0239,  0.0540,  0.0103,  0.0260, -0.0111,  0.0362,  0.0424,
#          0.1035, -0.0642], grad_fn=<SelectBackward0>) tensor(7)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 best_model, history = train(net, lr=0.002, epochs=50)
#
# Cell In[12], line 52, in train(model, lr, epochs, teacher, print_every, verbose)
#      50 # print(outputs[1], labels[1])
#      51 with torch.no_grad():
# ---> 52     acc = val_acc(model)
#      54 if acc > best_acc:
#      55     best_acc = acc
#
# Cell In[11], line 3, in val_acc(net)
#       1 def val_acc(net):
#       2     correct, total = 0, 0
# ----> 3     for i, data in enumerate(validloader, 0):
#       4         inputs, labels = data
#       5         inputs, labels = inputs.to(device), labels.to(device)
#
# File /opt/homebrew/anaconda3/envs/QML/lib/python3.12/site-packages/torch/utils/data/dataloader.py:627, in _BaseDataLoaderIter.__next__(self)
#     626 def __next__(self) -> Any:
# --> 627     with torch.autograd.profiler.record_function(self._profile_name):
#     628         if self._sampler_iter is None:
#     629             # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630             self._reset()  # type: ignore[call-arg]
#
# File /opt/homebrew/anaconda3/envs/QML/lib/python3.12/site-packages/torch/autograd/profiler.py:605, in record_function.__enter__(self)
#     604 def __enter__(self):
# --> 605     self.record = torch.ops.profiler._record_function_enter_new(
#     606         self.name, self.args
#     607     )
#     608     return self
#
# File /opt/homebrew/anaconda3/envs/QML/lib/python3.12/site-packages/torch/_ops.py:854, in OpOverloadPacket.__call__(self_, *args, **kwargs)
#     846 def __call__(self_, *args, **kwargs):  # noqa: B902
#     847     # use `self_` to avoid naming collide with aten ops arguments that
#     848     # named "self". This way, all the aten ops can be called by kwargs.
#    (...)
#     852     # We save the function ptr as the `op` attribute on
#     853     # OpOverloadPacket to access it here.
# --> 854     return self_._op(*args, **(kwargs or {}))
#
# KeyboardInterrupt:

# %%
plt.plot(history)
plt.legend(["Training loss", "Validation Accuracy"])
plt.show()

# %%
plt.plot([x[0] for x in history])
plt.legend(["Training loss"])
plt.show()

# %%
PATH = './trained_models/quadnet.pth'
torch.save(best_model.state_dict(), PATH)

# %%
dataiter = iter(testloader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join(f'{labels[j]:5d}' for j in range(batch_size)))
# Out:
# GroundTruth:      1

# %%
net = arch(len(classes))
net.load_state_dict(torch.load(PATH))
outputs = net(images)

# %%
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join(f'{predicted[j]:5d}'
                              for j in range(batch_size)))
# Out:
# Predicted:      1

# %%
errors = []

correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        images, labels = data
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        for i in range(len(predicted)):
            if labels[i] != predicted[i]:
                errors.append(images[i])

print(f'Accuracy of the network on the test images: {100 * correct / total} %')
# Out:
# Accuracy of the network on the test images: 99.84060009376465 %

# %%
print("Incorrectly predicted images")
imshow(torchvision.utils.make_grid(errors))
# Out:
# Incorrectly predicted images

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[label.item()] += 1
            total_pred[label.item()] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Recall for class: {classname:5d} is {accuracy:.1f} %')
# Out:
# Recall for class:     0 is 99.9 %
# Recall for class:     1 is 99.8 %

# %% [markdown]
# # Training an ensemble

# %%
# torch.use_deterministic_algorithms(False)

# for i in range(5):
#     acc = 0
#     # only allow accuracy models
#     while acc < .9:
#         model, _ = train(arch(len(classes)), verbose=False)
#         with torch.no_grad():
#             acc = val_acc(model)
#             print(i, acc)

#     PATH = f'./trained_models/clnet{i}.pth'
#     torch.save(model.state_dict(), PATH)
#     print(f"Finished model {i}")
