# %%
from models.quadnet import QuadraticNet
from models.cnet import SNet

arch = QuadraticNet

# %%
classes = range(10)

# %%
s_params = sum(p.numel() for p in SNet(len(classes)).parameters() if p.requires_grad)
quad_params = sum(p.numel() for p in QuadraticNet(len(classes)).parameters() if p.requires_grad)
print(f"SNet has {s_params} parameters")
print(f"QuadNet has {quad_params} parameters")
# Out:
# SNet has 77012 parameters
# QuadNet has 38188 parameters

# %%
import torch
import torchvision
import torch.nn as nn
import torchvision.transforms as transforms

import numpy as np

# %%
manualSeed = 999
torch.manual_seed(manualSeed)
torch.use_deterministic_algorithms(True)

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5,), (0.5,))])

batch_size = 1

classes = range(10)

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5,), (0.5,))])

batch_size = 1
n_train = 1000  # We will concentrate on the first 100 samples
n_valid = 4000

# Use pre-defined torchvision function to load MNIST train data
X_train = torchvision.datasets.MNIST(
    root="./data", train=True, download=True, transform=transform
)

# Filter out labels (originally 0-9), leaving only labels 0 and 1
idx = np.concatenate(
    [np.where(X_train.targets == c)[0][:n_train] for c in classes]
)
X_train.data = X_train.data[idx]
X_train.targets = X_train.targets[idx]



# Use pre-defined torchvision function to load MNIST train data
X_test = torchvision.datasets.MNIST(
    root="./data", train=True, download=True, transform=transform
)
idx = np.concatenate(
    [np.where(X_test.targets == c)[0][n_train:] for c in classes]
)
X_test.data = X_test.data[idx]
X_test.targets = X_test.targets[idx]



X_valid = torchvision.datasets.MNIST(
    root="./data", train=False, download=True, transform=transform
)
idx = np.concatenate(
    [np.where(X_valid.targets == c)[0][:n_valid] for c in classes]
)
X_valid.data = X_valid.data[idx]
X_valid.targets = X_valid.targets[idx]

# Define torch dataloader with filtered data
trainloader = torch.utils.data.DataLoader(X_train, batch_size=batch_size, shuffle=True)
validloader = torch.utils.data.DataLoader(X_valid, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(X_test, batch_size=batch_size, shuffle=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join(f'{labels[j]:5d}' for j in range(batch_size)))
# Out:
#     4

# %%
device = torch.device('cpu')

net = arch(len(classes)).to(device)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
def val_acc(net):
    correct, total = 0, 0
    for i, data in enumerate(validloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = torch.argmax(net(inputs), dim = 1)
        correct += torch.sum(outputs == labels).item()

        total += 1

    return correct / batch_size / total

# %%
best_acc, best_epoch, best_model = 0, -1, arch(num_classes=len(classes))
history = []

def train(model, lr=0.002, epochs=15, teacher=None, print_every=100, verbose=True):
    global best_acc, best_model, history
    best_epoch = -1

    optimizer = optim.Adam(net.parameters(), lr=lr)
    
    patience = 3
    for epoch in range(epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data

            # labels = torch.tensor([1. if labels.item() == x else 0. for x in classes]).view(1, -1)

            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)

            if teacher is None:
                loss = criterion(outputs, labels)
            else:
                with torch.no_grad():
                    teacher_preds = teacher(inputs).detach()
                    
                teaching_loss = criterion(outputs, teacher_preds)
                loss = criterion(outputs, labels) + teaching_loss
                    
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            
            
                
            # if i == batches: break
            if (i+1) % print_every == 0:
                if verbose:
                    print(f'[{epoch + 1}, {i+1}] loss: {running_loss / print_every:.3f}')
                    print(outputs[0], labels[0])
                # print(outputs[1], labels[1])
                with torch.no_grad():
                    acc = val_acc(model)
                
                if acc > best_acc:
                    best_acc = acc
                    best_epoch = epoch
                    best_model.load_state_dict(model.state_dict())

                history.append([running_loss / print_every, acc])
                running_loss = 0.0
                if verbose:
                    print(f"Validation Accuracy: {acc:.3f}")

                

                if acc == 1: break
        if acc == 1: break

        if best_acc > 0.6 and epoch > best_epoch + patience: break
                
            

        # print(f'{epoch + 1} loss: {running_loss / n_samples:.3f}')
        # print(outputs[0], labels[0])
        # # print(outputs[1], labels[1])
        # with torch.no_grad():
        #     acc = val_acc(model)
        # print("Validation Accuracy:", acc)
        
        # if acc > best_acc:
        #     best_acc = acc
        #     best_batch = i
        #     best_model.load_state_dict(model.state_dict())

        # if i > best_batch + batch_patience: break

        # history.append([running_loss / n_samples, acc])
        
        # running_loss = 0.0


    print('Finished Training')
    return best_model, history

# %%
best_model, history = train(net, lr=0.002, epochs=50)
# Out:
# [1, 100] loss: 2.344
# tensor([ 0.1301,  0.1810,  0.0487,  0.0225, -0.0564, -0.2020,  0.0888, -0.1497,
#         -0.2108, -0.2512], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.114
# [1, 200] loss: 2.313
# tensor([ 0.1472,  0.1789,  0.0442, -0.0514, -0.0338, -0.2119,  0.0365, -0.1224,
#         -0.1540, -0.1970], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.141
# [1, 300] loss: 2.278
# tensor([ 0.0991,  0.1805,  0.0402,  0.0210, -0.0900, -0.2300,  0.0868, -0.1289,
#         -0.2253, -0.2076], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.210
# [1, 400] loss: 2.264
# tensor([ 0.0646,  0.1876,  0.0592,  0.0427, -0.1304, -0.2630,  0.0672, -0.0524,
#         -0.2251, -0.1998], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.149
# [1, 500] loss: 2.136
# tensor([ 1.6045, -4.7129, -3.0735, -1.5651,  1.0528,  0.7374,  0.4611, -1.3665,
#         -3.0350,  0.5973], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.210
# [1, 600] loss: 2.191
# tensor([ 0.0319,  0.1128,  0.0121,  0.0410, -0.1797, -0.1902, -0.0132, -0.0302,
#         -0.1781, -0.1487], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.148
# [1, 700] loss: 2.141
# tensor([-0.0718,  0.2463,  0.2859, -0.0226, -0.2933, -0.2866, -0.0956,  0.0862,
#         -0.1718, -0.1866], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.248
# [1, 800] loss: 2.067
# tensor([-0.1066,  0.2095,  0.1644,  0.0183, -0.3115, -0.2914, -0.0367, -0.0408,
#         -0.0325, -0.1522], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.312
# [1, 900] loss: 1.946
# tensor([ 10.7256, -32.9282, -16.1722, -10.6981,   1.4367,   0.6510,   5.2088,
#          -4.3149, -24.6975,   2.6487], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.354
# [1, 1000] loss: 1.568
# tensor([-1.8024, -9.4364, -3.2228, -2.4966,  1.7522,  1.4027, -1.7760, -2.7997,
#         -4.2363,  2.3817], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.389
# [1, 1100] loss: 1.411
# tensor([-1.8639, -1.1799, -0.4500,  0.6009, -0.2517,  0.0309,  0.3760, -0.5223,
#         -1.2535, -0.4295], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.517
# [1, 1200] loss: 1.487
# tensor([ -7.7021, -16.1891,  -6.0576,  -1.3176,   2.7917,   3.1122,   0.4099,
#          -3.3639,  -9.0631,  -0.4135], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.433
# [1, 1300] loss: 2.068
# tensor([-4.0931e-01,  3.1132e-02,  1.6628e-03, -7.7886e-02, -6.0008e-01,
#         -6.1644e-01, -2.6330e-01,  4.1600e-04, -2.6264e-01, -3.5183e-01],
#        grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.349
# [1, 1400] loss: 1.475
# tensor([-0.6835, -3.3720, -1.4331, -0.7330,  0.7129,  0.2892, -0.8565, -1.0476,
#         -1.0362,  0.7016], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.513
# [1, 1500] loss: 1.568
# tensor([ -4.4178, -15.6212,  -6.3758,  -1.7610,   0.6076,   1.6507,   5.5962,
#          -1.4570,  -9.6409,  -4.2433], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.453
# [1, 1600] loss: 1.315
# tensor([-1.0772,  0.7792,  0.6370, -0.2310, -1.5153, -1.2825, -1.3346,  0.6270,
#          0.6311, -1.0246], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.560
# [1, 1700] loss: 1.292
# tensor([-7.7228, -7.5239, -2.6949,  2.4442,  0.1374,  1.8038, -0.7059, -2.5991,
#         -4.0403, -0.6107], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.580
# [1, 1800] loss: 1.244
# tensor([-0.3909, -0.0644, -0.0794, -0.3958, -0.7477, -0.8313, -1.0101,  0.0626,
#          0.2374, -0.4264], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.492
# [1, 1900] loss: 1.189
# tensor([-0.5759,  0.1911,  0.2889, -0.2108, -1.5286, -1.3434, -1.4872,  0.1411,
#          0.0579, -0.8484], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.650
# [1, 2000] loss: 1.215
# tensor([-1.6413,  1.4428,  0.9105, -0.4813, -3.0617, -2.2221, -2.8519,  1.3271,
#          1.2928, -1.7545], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.687
# [1, 2100] loss: 1.050
# tensor([ -6.6274, -18.7168,  -8.9124,  -1.2146,   0.3947,   3.6225,   1.5524,
#          -4.4621,  -8.1335,  -2.3127], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.699
# [1, 2200] loss: 0.751
# tensor([-0.4483, -0.7882, -0.8948, -0.1547, -0.6840, -0.2059,  0.1976, -0.3940,
#         -0.4141, -0.7451], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.750
# [1, 2300] loss: 1.179
# tensor([-11.4523,  -6.6678,  -4.0734,   4.0687,  -1.2544,   2.1842,  -0.5440,
#          -3.0537,  -4.3598,  -1.7134], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.653
# [1, 2400] loss: 1.106
# tensor([-0.4061, -0.3644,  0.1256, -0.0419, -1.4255, -1.6432, -1.3617, -0.6289,
#         -0.5384, -0.5550], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.676
# [1, 2500] loss: 0.968
# tensor([  7.0360, -30.5798,  -6.6772,  -7.5392,  -0.4711,  -5.7078,   3.0592,
#         -11.4400, -16.5527,  -2.6322], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.709
# [1, 2600] loss: 0.889
# tensor([ 1.4643, -7.1884, -1.3438, -1.5603, -1.0236, -2.7199, -0.5539, -3.0929,
#         -4.1943, -0.6152], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.733
# [1, 2700] loss: 0.885
# tensor([ 10.1809, -44.3181,  -9.6489, -11.6019,  -1.7675,  -9.4349,   2.4773,
#         -12.2111, -20.6730,  -5.4599], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.794
# [1, 2800] loss: 0.591
# tensor([ -4.5186, -22.0643,  -9.1256,  -4.7257,  -1.6576,   2.5489,   9.4499,
#          -4.2574,  -8.2272,  -7.9989], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.781
# [1, 2900] loss: 0.720
# tensor([  5.9221, -23.7439,  -5.6139,  -6.5492,  -0.0710,  -4.4320,   2.7699,
#          -7.5615, -10.8883,  -3.7722], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.741
# [1, 3000] loss: 0.892
# tensor([-1.6577, -6.0555, -3.9123, -3.8805,  0.6498, -1.6305, -4.7844, -0.5944,
#         -0.3295,  1.2694], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.738
# [1, 3100] loss: 0.722
# tensor([  9.3624, -37.7163,  -8.4619,  -9.5544,  -0.8260,  -8.3813,   2.7708,
#         -12.1526, -17.3768,  -2.8486], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.785
# [1, 3200] loss: 0.563
# tensor([  4.8048, -18.7024,  -4.4524,  -4.6259,  -0.1638,  -4.8554,   1.6363,
#          -6.4162,  -9.2180,  -2.1655], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.755
# [1, 3300] loss: 0.552
# tensor([-4.7587,  3.1776,  2.1779, -1.1126, -7.6231, -8.0277, -6.1899,  3.3069,
#          2.4793, -3.3813], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.815
# [1, 3400] loss: 0.540
# tensor([-12.0479,   6.5021,   6.1705,  -3.3639, -19.2432, -18.9035, -16.3866,
#           8.7487,   5.1282,  -7.8169], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.790
# [1, 3500] loss: 0.645
# tensor([-22.5072,  14.0948,  11.8066,  -6.4451, -35.6430, -33.9005, -29.6164,
#          16.1086,   9.4543, -14.4339], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.807
# [1, 3600] loss: 0.659
# tensor([ -8.8152,   2.9236,   2.1354,  -0.7594, -10.4872,  -8.1152,  -6.9689,
#           3.2532,   1.3151,  -4.1051], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.746
# [1, 3700] loss: 0.808
# tensor([-11.9553,   9.4159,   5.3214,  -2.2192, -20.2431, -18.1348, -16.1962,
#           8.4324,   5.2084,  -7.2615], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.740
# [1, 3800] loss: 0.843
# tensor([ 10.2900, -53.9868,  -6.0767, -13.3290,  -3.0242, -12.4165,   4.5403,
#         -18.7998, -26.4344,  -4.4656], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.794
# [1, 3900] loss: 0.641
# tensor([ -7.2216,   4.4084,   2.8812,  -0.6353, -12.5090, -11.1044, -10.0149,
#           4.3774,   2.0923,  -3.9335], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.819
# [1, 4000] loss: 0.546
# tensor([ -4.6262, -28.0002, -15.2634, -12.9816,   7.4661,   0.2231,  -8.2656,
#          -4.2765,  -0.9603,   3.8372], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.861
# [1, 4100] loss: 0.527
# tensor([-25.7428,  13.2454,  10.7270,  -1.8671, -42.8226, -40.8387, -34.1078,
#          17.1989,   5.8312, -14.8167], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.851
# [1, 4200] loss: 0.664
# tensor([ -9.5090, -16.0715,  -8.4228,  -0.2408,  -0.7963,   3.6439,  -2.0682,
#          -3.8224,  -0.3204,  -1.6011], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.839
# [1, 4300] loss: 0.547
# tensor([ -3.8646, -10.0033,   3.5408,  -0.5794, -11.0223, -15.0272, -11.3653,
#          -2.9588,  -8.4444,  -3.1650], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.861
# [1, 4400] loss: 0.553
# tensor([-45.0724, -29.1022, -11.5869,  15.2623, -16.9551,   6.3216,  -1.8689,
#          -8.8066,  -5.6066,  -9.0184], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.871
# [1, 4500] loss: 0.623
# tensor([-1.7067,  1.9151, -0.2790, -0.1022, -2.7891, -2.1156, -1.9281,  0.4747,
#          1.2406, -1.1548], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.767
# [1, 4600] loss: 0.662
# tensor([-15.3754, -27.0782, -10.7004,  -9.6805,  -5.0270,  -9.1774, -18.8849,
#          -4.7399,  -5.6167,   1.5000], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.820
# [1, 4700] loss: 0.629
# tensor([ -8.2350, -39.4037, -11.9090,  -7.5173,  -5.6176,   0.5171,  13.4430,
#          -7.4836,  -9.2839, -13.8946], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.855
# [1, 4800] loss: 0.625
# tensor([-51.2159, -28.2306,   0.5092, -18.9808, -40.2174, -50.8129, -50.0156,
#           8.3850, -18.5080, -17.6548], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.868
# [1, 4900] loss: 0.744
# tensor([  3.4394, -19.8596,   0.0695,  -2.7022,  -2.6494,  -7.4704,  -2.3463,
#          -7.8334, -11.3285,  -1.5215], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.864
# [1, 5000] loss: 0.409
# tensor([-13.4462, -16.3936,  11.2574,  -2.5702, -31.5626, -39.8718, -31.4009,
#          -1.7710, -18.8829, -10.7940], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.888
# [1, 5100] loss: 0.617
# tensor([ -3.6452, -22.5779,  -6.6993,  -4.0866,  -4.0467,   2.1192,   7.0791,
#          -3.6509,  -4.2882,  -8.4998], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.847
# [1, 5200] loss: 0.404
# tensor([ -3.7740, -22.8292,  -7.2321,  -4.0957,  -4.5137,   2.2242,   6.3027,
#          -3.5039,  -4.1049,  -7.4188], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.874
# [1, 5300] loss: 0.577
# tensor([ -7.1365, -17.5951,  -7.4319,  -5.2865,  -0.0322,  -2.8579, -10.7010,
#          -2.8433,  -2.0518,   1.9303], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.882
# [1, 5400] loss: 0.366
# tensor([-12.0623, -32.8050, -13.6485, -11.0823,   1.9785,  -4.6115, -18.0400,
#          -5.7830,  -6.3387,   4.6311], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.895
# [1, 5500] loss: 0.237
# tensor([ -9.7738, -78.0881,  21.6302,  -0.3719, -52.4016, -77.3089, -52.3925,
#         -24.8461, -71.6982, -12.6836], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.889
# [1, 5600] loss: 0.678
# tensor([-38.5752, -25.1125,  -7.7735,  10.5268, -24.7170,  -1.0781, -10.1821,
#          -0.9061,  -2.1701, -10.8693], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.865
# [1, 5700] loss: 0.426
# tensor([-3.2874, -8.2655, -4.7214, -2.9613, -1.1970, -2.5783, -7.4120, -1.8722,
#          0.3784,  0.8492], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.859
# [1, 5800] loss: 0.672
# tensor([ -5.5444,   3.3652,   2.5850,  -0.6761, -10.2107,  -9.5462,  -8.3167,
#           2.3457,   0.5779,  -4.3566], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.891
# [1, 5900] loss: 0.592
# tensor([-21.7695, -51.2106, -20.6177,  -0.7526,  -7.4074,   9.6260,  -6.6823,
#          -9.0362,  -0.4930,  -3.6584], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.819
# [1, 6000] loss: 0.355
# tensor([-11.7616, -22.6543,  10.1302,   1.2360, -34.6304, -41.2590, -32.5705,
#          -4.5365, -26.5632,  -8.9360], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.912
# [1, 6100] loss: 0.696
# tensor([-44.1111, -35.9830,  -8.9253,  13.5304, -25.2150,   3.1780,  -9.6531,
#          -3.7118,  -6.3865, -11.2904], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.859
# [1, 6200] loss: 0.588
# tensor([-1.0607e+01, -8.0607e+00, -2.6748e+00,  3.1303e+00, -7.0317e+00,
#         -1.0005e-02, -3.2331e+00, -1.4257e+00, -2.1056e-01, -3.0443e+00],
#        grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.899
# [1, 6300] loss: 0.459
# tensor([-0.8619,  1.5758, -0.2209, -0.1990, -1.9230, -1.5754, -1.2760, -0.4543,
#          0.8421, -0.7605], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.842
# [1, 6400] loss: 0.739
# tensor([ -4.1621,  -5.6892,  -4.5452,  -3.2930,  -4.5412,  -2.5300, -10.2184,
#          -1.4552,   3.7627,  -0.9250], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.893
# [1, 6500] loss: 0.302
# tensor([-19.5028, -18.7030,  -5.7965,   7.0661, -10.4082,   3.3631,  -2.9722,
#          -3.1331,  -3.2034,  -4.6739], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.894
# [1, 6600] loss: 0.274
# tensor([ -8.7751,   5.3928,   1.9359,  -1.9790, -11.9526, -10.3047, -10.2166,
#           3.6412,  -0.9929,  -4.1842], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.911
# [1, 6700] loss: 0.278
# tensor([-45.5701,  14.2774,  10.1015, -11.3887, -56.6497, -52.9886, -52.3244,
#          17.2304, -16.6143, -15.5584], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.889
# [1, 6800] loss: 0.383
# tensor([-17.6435, -46.0219, -19.0668,  -0.3032,  -4.4406,   8.4013,  -7.4219,
#          -8.0630,  -4.0337,  -2.6094], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.909
# [1, 6900] loss: 0.143
# tensor([ -8.8721,   6.6016,   2.1125,  -2.1190, -12.5226, -11.1887, -11.0456,
#           3.6702,  -0.6867,  -3.9393], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.929
# [1, 7000] loss: 0.280
# tensor([-2.4393, -7.6951, -5.6298, -4.0031,  1.2957, -0.6244, -3.5715, -2.1275,
#         -0.7762,  0.2695], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.915
# [1, 7100] loss: 0.691
# tensor([-19.4149, -16.2712,  -3.5695,   6.0955, -13.7762,  -0.5310,  -6.6488,
#          -2.6899,  -5.7634,  -4.5845], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.885
# [1, 7200] loss: 0.576
# tensor([-48.5517, -16.6010,   1.4543, -12.1133, -40.3555, -42.6231, -39.8294,
#           7.8623, -35.0124, -12.1363], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.882
# [1, 7300] loss: 0.358
# tensor([  2.4096, -13.2068,  -1.3571,  -2.6468,  -2.5849,  -3.1237,  -0.7569,
#          -5.1237,  -7.0386,  -1.8964], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.928
# [1, 7400] loss: 0.505
# tensor([  1.8285, -14.5502,  -3.2845,  -4.2688,  -3.2509,  -2.3105,  -2.0054,
#          -5.8651,  -5.6329,  -3.1028], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.838
# [1, 7500] loss: 0.624
# tensor([-81.2597, -15.8581,  -0.7717, -16.4669, -69.6059, -65.1923, -64.5926,
#          15.4938, -54.3682, -22.7516], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.872
# [1, 7600] loss: 0.292
# tensor([-65.6800, -21.4111,  -2.0977, -13.0087, -52.7380, -49.5188, -46.6513,
#           5.9537, -48.5106, -15.0757], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.918
# [1, 7700] loss: 0.271
# tensor([ -5.0127,  -8.0292,  -5.7693,  -5.0998,  -2.6288,  -5.3609, -10.4894,
#          -1.7431,  -2.9571,   1.0665], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.888
# [1, 7800] loss: 0.311
# tensor([-6.0770,  7.3806,  1.8336, -1.0574, -9.5533, -8.8533, -8.8769,  3.0622,
#          0.5410, -3.7797], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.916
# [1, 7900] loss: 0.228
# tensor([ -7.3782, -70.1370, -20.7678, -22.0001,  -8.7503,   8.6066,  24.1472,
#         -16.7317, -21.9613, -25.6471], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.888
# [1, 8000] loss: 0.405
# tensor([-4.3973,  5.3181,  0.9654, -0.6760, -6.6997, -6.5915, -6.2277,  1.7460,
#          0.8707, -2.8608], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.891
# [1, 8100] loss: 0.294
# tensor([-1.3436, -5.6089, -2.4617, -1.7836, -1.8426,  0.5316,  2.3523, -2.5857,
#         -1.3187, -2.8365], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.924
# [1, 8200] loss: 0.541
# tensor([-0.9742, -9.4881, -4.8588, -3.0018, -0.0610,  0.7040, -0.5034, -3.2129,
#         -0.7132, -1.1633], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.919
# [1, 8300] loss: 0.358
# tensor([-6.8669,  4.9477,  1.4692, -0.9114, -8.9104, -8.7984, -7.9757,  2.6267,
#         -0.6757, -3.8731], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.923
# [1, 8400] loss: 0.229
# tensor([  8.0413, -60.8780,  -7.8871, -18.3553, -11.9035, -11.6726,  -0.4631,
#         -20.5334, -27.0853, -13.7125], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.922
# [1, 8500] loss: 0.169
# tensor([-19.4239, -25.0351, -20.8166, -14.4965, -15.8097, -10.2527, -40.6213,
#          -7.0636,  10.9084, -10.1233], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.937
# [1, 8600] loss: 0.369
# tensor([-11.8490, -51.5744, -26.1283, -18.6396,   6.6349,  -2.2788,  -5.9226,
#         -12.8589, -13.7676,  -1.6055], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.923
# [1, 8700] loss: 0.431
# tensor([  9.6622, -96.3683, -33.2453, -39.2094, -15.6949, -19.2304, -23.9830,
#         -28.5733, -24.1793, -17.9815], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.911
# [1, 8800] loss: 0.432
# tensor([-25.5826, -12.4907,  -2.1534,   6.5883, -22.1018,  -6.2509,  -5.6269,
#          -0.2308,  -9.2649,  -7.8208], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.908
# [1, 8900] loss: 0.349
# tensor([ -7.2101,   8.3575,   2.3778,  -0.7634, -11.2793, -11.6114, -10.4407,
#           3.8591,   0.2292,  -4.5634], grad_fn=<SelectBackward0>) tensor(1)
# Validation Accuracy: 0.907
# [1, 9000] loss: 0.455
# tensor([  2.4449, -18.1491,  -5.9038,  -7.8661,  -2.7148,  -2.5208,  -1.7803,
#          -7.2092,  -5.3316,  -4.2812], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.915
# [1, 9100] loss: 0.291
# tensor([ -9.0533, -31.5273, -18.6977, -14.9007,   6.8559,  -2.7893,  -9.2376,
#          -6.8081,  -7.9598,   0.6764], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.927
# [1, 9200] loss: 0.235
# tensor([ -6.6153, -11.9430,  -6.9155,  -3.7336,  -2.3805,  -2.4860, -11.0086,
#          -3.2217,   0.1515,   0.2689], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.932
# [1, 9300] loss: 0.137
# tensor([ -28.5143, -138.1005,   40.0121,  -12.0582, -130.8837, -120.5119,
#         -118.2083,  -31.6369, -126.2784,  -16.7984], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.919
# [1, 9400] loss: 0.592
# tensor([ -6.7886, -13.0072,  -7.1005,  -5.1272,  -0.0583,  -4.2367,  -9.1708,
#          -2.8620,  -3.6917,   1.7403], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.929
# [1, 9500] loss: 0.564
# tensor([-12.4258, -22.9133, -11.9386,  -9.1498,   0.2326,  -6.7665, -14.8364,
#          -4.1250,  -7.1607,   4.1467], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.842
# [1, 9600] loss: 0.242
# tensor([  2.5412, -19.8344,  -2.9024,  -6.4784,  -2.7358,  -4.7419,  -0.1630,
#          -7.4442,  -9.2715,  -2.9406], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.917
# [1, 9700] loss: 0.446
# tensor([-11.7865,  -8.4476,  -0.7802,   2.3687, -11.5276,  -2.7576,  -3.4598,
#          -1.8093,  -6.3800,  -3.7143], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.893
# [1, 9800] loss: 0.353
# tensor([ -6.8241, -16.8077,   6.2101,  -3.2917, -18.7787, -18.1906, -18.3702,
#          -4.1208, -15.1290,  -2.0355], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.920
# [1, 9900] loss: 0.307
# tensor([ -7.9548, -23.2257, -14.0937, -12.3767,   4.2752,  -4.6570,  -6.0418,
#          -5.8845,  -7.7373,   1.0931], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.932
# [1, 10000] loss: 0.363
# tensor([-15.3483, -42.3051, -23.7053, -22.3631,   7.3881,  -8.4850, -11.3707,
#          -9.2667, -16.0377,   2.4532], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.931
# [2, 100] loss: 0.160
# tensor([ -2.5982, -54.5018, -17.2852, -22.3397,  -6.2815,   2.1003,  18.3395,
#         -18.9305, -19.1828, -22.7907], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.942
# [2, 200] loss: 0.307
# tensor([-103.6592,  -32.0265,  -12.9168,  -10.5836,  -73.5054,  -60.7535,
#          -56.0200,   14.2585,  -56.5929,  -29.8495], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.922
# [2, 300] loss: 0.176
# tensor([ 0.2681, -1.2877, -0.4924, -1.2768, -1.0959, -1.1623, -0.3454, -2.0320,
#         -0.4014, -1.2846], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.934
# [2, 400] loss: 0.151
# tensor([  8.9006, -80.5136,  -2.5949, -27.9267, -12.2382, -15.0418,  -1.2804,
#         -29.5700, -42.4673, -12.8731], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.920
# [2, 500] loss: 0.543
# tensor([ -8.5400, -21.4350, -13.1801, -11.8537,   4.9508,  -4.0838,  -5.7429,
#          -5.2599,  -6.1596,   0.3604], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.902
# [2, 600] loss: 0.630
# tensor([-0.5127, -0.0822, -1.1563, -0.8560, -0.7887, -0.7311, -1.1305, -1.6173,
#          1.1275, -0.8601], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.894
# [2, 700] loss: 0.393
# tensor([ -9.5016,  -8.3454,  -1.8308,  -6.1218, -13.4793,  -8.7056, -14.0631,
#          -5.5561,   0.4119,  -8.8303], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.910
# [2, 800] loss: 0.684
# tensor([ -6.5794, -13.8036,  -7.6072,  -2.9258,  -2.2687,   1.6831,  -2.2201,
#          -5.1290,  -0.7860,  -2.0058], grad_fn=<SelectBackward0>) tensor(5)
# Validation Accuracy: 0.873
# [2, 900] loss: 0.378
# tensor([-58.7171, -24.8615,  -9.9128,  -8.3314, -41.3094, -36.5272, -30.8867,
#           5.9890, -35.9382, -10.9149], grad_fn=<SelectBackward0>) tensor(7)
# Validation Accuracy: 0.937
# [2, 1000] loss: 0.203
# tensor([-15.5273, -57.5374, -31.2737, -29.0496,  11.4803,  -5.6228, -13.0313,
#         -16.6143, -11.5650,   1.4817], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.934
# [2, 1100] loss: 0.208
# tensor([ -3.8642, -34.5683, -13.9139, -16.4884,  -3.3876,   2.5003,  10.4037,
#         -14.4231,  -8.4962, -12.5244], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.913
# [2, 1200] loss: 0.381
# tensor([-33.2659, -31.6909,  -7.5335,  10.0999, -30.3260,   1.6896,  -7.4429,
#          -8.0115, -17.5169,  -2.4391], grad_fn=<SelectBackward0>) tensor(3)
# Validation Accuracy: 0.935
# [2, 1300] loss: 0.246
# tensor([ -6.4647,  -6.1386,  -5.7953,  -6.3811,  -6.7241,  -4.0385, -10.0790,
#          -3.8366,   3.2109,  -3.6190], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.921
# [2, 1400] loss: 0.392
# tensor([-21.8322, -16.8206,  12.6626,  -9.2741, -43.1120, -45.3350, -38.6536,
#          -0.4231, -21.3302,  -7.3994], grad_fn=<SelectBackward0>) tensor(2)
# Validation Accuracy: 0.923
# [2, 1500] loss: 0.265
# tensor([ -7.6085,  -4.1775,  -4.2896,  -5.0185,  -8.4278,  -4.2879, -10.1271,
#          -3.8588,   3.3098,  -4.5033], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.929
# [2, 1600] loss: 0.243
# tensor([  3.1298, -17.4388,  -6.3832, -11.4681,   0.4881,  -0.3431,   7.3752,
#          -8.6313,  -3.2578,  -8.1355], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.926
# [2, 1700] loss: 0.562
# tensor([-0.2248, -4.0123, -2.1626, -2.5783, -1.3156, -0.0553,  1.7295, -3.0927,
#         -0.5193, -2.4638], grad_fn=<SelectBackward0>) tensor(8)
# Validation Accuracy: 0.914
# [2, 1800] loss: 0.199
# tensor([-24.1973, -58.2469, -30.6156, -32.6161,  10.6887, -12.3089, -16.8676,
#         -13.0493, -19.3496,   3.6331], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.937
# [2, 1900] loss: 0.259
# tensor([   9.9550, -172.0892,  -46.3447,  -91.6271,  -19.1429,  -25.8904,
#          -14.4551,  -63.9687,  -46.8470,  -32.3342], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.924
# [2, 2000] loss: 0.288
# tensor([   3.9066, -118.3523,  -34.3316,  -65.9283,  -18.1674,  -16.1672,
#          -14.2847,  -46.0224,  -29.6706,  -24.2430], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.927
# [2, 2100] loss: 0.297
# tensor([-34.8575, -80.1020, -41.6335, -47.1431,  14.4565, -19.4113, -23.0232,
#         -17.9890, -30.4966,   3.2184], grad_fn=<SelectBackward0>) tensor(4)
# Validation Accuracy: 0.922
# [2, 2200] loss: 0.647
# tensor([-1.5256, -5.3789, -3.5432, -3.7327, -0.2437, -1.5839, -2.6522, -2.3131,
#         -0.6841, -0.0163], grad_fn=<SelectBackward0>) tensor(9)
# Validation Accuracy: 0.918
# [2, 2300] loss: 0.197
# tensor([ -3.0617, -17.3260,  -9.2521, -13.4711,  -6.3291,  -3.8555,  -6.7922,
#          -7.0152,  -0.7136,  -5.7539], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.941
# [2, 2400] loss: 0.141
# tensor([ -4.0483, -49.9430, -19.2461, -26.4619,  -7.0940,   3.7893,  17.8601,
#         -17.6375, -15.4519, -22.6209], grad_fn=<SelectBackward0>) tensor(6)
# Validation Accuracy: 0.890
# [2, 2500] loss: 0.373
# tensor([  11.7215, -227.9560,  -55.4667, -122.2025,  -33.9075,  -37.7192,
#          -29.0691,  -72.1309,  -77.4214,  -51.6170], grad_fn=<SelectBackward0>) tensor(0)
# Validation Accuracy: 0.925
# [2, 2600] loss: 0.295
# tensor([   3.1130, -290.9200,  -57.3888, -156.2299,  -80.8418,  -62.5784,
#          -62.3737,  -97.3240, -101.5152,  -71.6891], grad_fn=<SelectBackward0>) tensor(0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 best_model, history = train(net, lr=0.002, epochs=50)
#
# Cell In[12], line 52, in train(model, lr, epochs, teacher, print_every, verbose)
#      50 # print(outputs[1], labels[1])
#      51 with torch.no_grad():
# ---> 52     acc = val_acc(model)
#      54 if acc > best_acc:
#      55     best_acc = acc
#
# Cell In[11], line 7, in val_acc(net)
#       4 inputs, labels = data
#       5 inputs, labels = inputs.to(device), labels.to(device)
# ----> 7 outputs = torch.argmax(net(inputs), dim = 1)
#       8 correct += torch.sum(outputs == labels).item()
#      10 total += 1
#
# File /opt/homebrew/anaconda3/envs/QML/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/QML/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Documents/GitHub/Quantum/Digit-Classifier/models/quadnet.py:44, in QuadraticNet.forward(self, x)
#      42 # x = F.relu(self.fc2(x))
#      43 x = F.relu(self.fc3(x))
# ---> 44 x = F.relu(self.fc4(x))
#      45 x = self.fc5(x)
#      46 return x
#
# File /opt/homebrew/anaconda3/envs/QML/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/QML/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/Documents/GitHub/Quantum/Digit-Classifier/models/quadnet.py:21, in Quadratic.forward(self, x)
#      20 def forward(self, x):
# ---> 21     x = Quadratic.expand(x)
#      22     x = self.fc(x)
#      23     return x
#
# File ~/Documents/GitHub/Quantum/Digit-Classifier/models/quadnet.py:15, in Quadratic.expand(x)
#      13 x = x.view(x.shape[0], 1, *x.shape[1:]) # insert a dim after batch for transposing
#      14 xt = torch.transpose(x, 1, 2) # transpose per sample
# ---> 15 x = torch.concat((x, torch.ones((x.shape[0], 1, 1))), dim=-1) # append mul id to retain original linear relationships
#      17 x = torch.flatten(xt @ x, start_dim=1, end_dim=-1) # cross every pair of inputs to get all quadratic relationships
#      18 return x
#
# KeyboardInterrupt:

# %%
plt.plot(history)
plt.legend(["Training loss", "Validation Accuracy"])
plt.show()

# %%
plt.plot([x[0] for x in history])
plt.legend(["Training loss"])
plt.show()

# %%
PATH = './trained_models/quadnet.pth'
torch.save(best_model.state_dict(), PATH)

# %%
dataiter = iter(testloader)
images, labels = next(dataiter)

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join(f'{labels[j]:5d}' for j in range(batch_size)))
# Out:
# GroundTruth:      5

# %%
net = arch(len(classes))
net.load_state_dict(torch.load(PATH))
outputs = net(images)

# %%
_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join(f'{predicted[j]:5d}'
                              for j in range(batch_size)))
# Out:
# Predicted:      5

# %%
errors = []

correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        images, labels = data
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        for i in range(len(predicted)):
            if labels[i] != predicted[i]:
                errors.append(images[i])

print(f'Accuracy of the network on the test images: {100 * correct / total} %')
# Out:
# Accuracy of the network on the test images: 93.624 %

# %%
print("Incorrectly predicted images")
imshow(torchvision.utils.make_grid(errors))
# Out:
# Incorrectly predicted images

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[label.item()] += 1
            total_pred[label.item()] += 1


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Recall for class: {classname:5d} is {accuracy:.1f} %')
# Out:
# Recall for class:     0 is 98.0 %
# Recall for class:     1 is 96.4 %
# Recall for class:     2 is 93.7 %
# Recall for class:     3 is 92.1 %
# Recall for class:     4 is 88.3 %
# Recall for class:     5 is 95.4 %
# Recall for class:     6 is 98.3 %
# Recall for class:     7 is 94.3 %
# Recall for class:     8 is 83.7 %
# Recall for class:     9 is 95.5 %

# %% [markdown]
# # Training an ensemble

# %%
# torch.use_deterministic_algorithms(False)

# for i in range(5):
#     acc = 0
#     # only allow accuracy models
#     while acc < .9:
#         model, _ = train(arch(len(classes)), verbose=False)
#         with torch.no_grad():
#             acc = val_acc(model)
#             print(i, acc)

#     PATH = f'./trained_models/clnet{i}.pth'
#     torch.save(model.state_dict(), PATH)
#     print(f"Finished model {i}")
